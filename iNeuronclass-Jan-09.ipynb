# %%
import requests

# %%
url = 'https://api.github.com/repos/pandas-dev/pandas/issues'
resp = requests.get(url)
resp
# Out:
# <Response [200]>

# %%
data=resp.json()
data
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39109',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39109/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39109/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39109/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/39109',
#   'id': 783486912,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NTUyODM4OTU1',
#   'number': 39109,
#   'title': 'DOC: NDFrame fillna method add use case',
#   'user': {'login': 'BeanNan',
#    'id': 40813941,
#    'node_id': 'MDQ6VXNlcjQwODEzOTQx',
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/40813941?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/BeanNan',
#    'html_url': 'https://github.com/BeanNan',
#    'followers_url': 'https://api.github.com/users/BeanNan/followers',
#    'following_url': 'https://api.github.com/users/BeanNan/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/BeanNan/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/BeanNan/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/BeanNan/subscriptions',
#    'organizations_url': 'https://api.github.com/users/BeanNan/orgs',
#    'repos_url': 'https://api.github.com/users/BeanNan/repos',
#    'events_url': 'https://api.github.com/users/BeanNan/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/BeanNan/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-01-11T15:49:45Z',
#   'updated_at': '2021-01-11T15:49:45Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/39109',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/39109',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/39109.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/39109.patch'},
#   'body': '- [x] closes #38917 \r\n- [ ] tests added / passed\r\n- [ ] Ensure all linting tests pass, see [here](https://pandas.pydata.org/pandas-docs/dev/development/contributing.html#code-standards) for how to run them\r\n- [ ] whatsnew entry\r\n\r\ncc @MarcoGorelli',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39108',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39108/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39108/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39108/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/39108',
#   'id': 783413847,
#   'node_id': 'MDU6SXNzdWU3ODM0MTM4NDc=',
#   'number': 39108,
#   'title': 'TYP: clean notations in the wrong place',
#   'user': {'login': 'jreback',
#    'id': 953992,
#    'node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/953992?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jreback',
#    'html_url': 'https://github.com/jreback',
#    'followers_url': 'https://api.github.com/users/jreback/followers',
#    'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jreback/orgs',
#    'repos_url': 'https://api.github.com/users/jreback/repos',
#    'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jreback/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 1280988427,
#     'node_id': 'MDU6TGFiZWwxMjgwOTg4NDI3',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Typing',
#     'name': 'Typing',
#     'color': 'ea91a4',
#     'default': False,
#     'description': 'mypy type annotations'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/80',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/80',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/80/labels',
#    'id': 6095818,
#    'node_id': 'MDk6TWlsZXN0b25lNjA5NTgxOA==',
#    'number': 80,
#    'title': '1.3',
#    'description': '',
#    'creator': {'login': 'jreback',
#     'id': 953992,
#     'node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#     'avatar_url': 'https://avatars2.githubusercontent.com/u/953992?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jreback',
#     'html_url': 'https://github.com/jreback',
#     'followers_url': 'https://api.github.com/users/jreback/followers',
#     'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jreback/orgs',
#     'repos_url': 'https://api.github.com/users/jreback/repos',
#     'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jreback/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 77,
#    'closed_issues': 461,
#    'state': 'open',
#    'created_at': '2020-11-11T19:05:43Z',
#    'updated_at': '2021-01-11T14:52:28Z',
#    'due_on': '2021-05-31T07:00:00Z',
#    'closed_at': None},
#   'comments': 2,
#   'created_at': '2021-01-11T14:25:42Z',
#   'updated_at': '2021-01-11T14:27:43Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'body': 'https://github.com/pandas-dev/pandas/blob/master/pandas/core/groupby/groupby.py#L1294\r\n\r\n```\r\n# To track operations that expand dimensions, like ohlc\r\nOutputFrameOrSeries = TypeVar("OutputFrameOrSeries", bound=NDFrame)\r\n```\r\n\r\nat the very least this should be in `pandas._typing`. puzzled why we need this at *all*, as this is the same as `FrameOrSeries`',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39107',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39107/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39107/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39107/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/39107',
#   'id': 783404734,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NTUyNzY5NjIz',
#   'number': 39107,
#   'title': 'TYP: replace Label alias from pandas._typing with Hashable',
#   'user': {'login': 'simonjayhawkins',
#    'id': 13159005,
#    'node_id': 'MDQ6VXNlcjEzMTU5MDA1',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/13159005?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/simonjayhawkins',
#    'html_url': 'https://github.com/simonjayhawkins',
#    'followers_url': 'https://api.github.com/users/simonjayhawkins/followers',
#    'following_url': 'https://api.github.com/users/simonjayhawkins/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/simonjayhawkins/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/simonjayhawkins/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/simonjayhawkins/subscriptions',
#    'organizations_url': 'https://api.github.com/users/simonjayhawkins/orgs',
#    'repos_url': 'https://api.github.com/users/simonjayhawkins/repos',
#    'events_url': 'https://api.github.com/users/simonjayhawkins/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/simonjayhawkins/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 1280988427,
#     'node_id': 'MDU6TGFiZWwxMjgwOTg4NDI3',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Typing',
#     'name': 'Typing',
#     'color': 'ea91a4',
#     'default': False,
#     'description': 'mypy type annotations'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/80',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/80',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/80/labels',
#    'id': 6095818,
#    'node_id': 'MDk6TWlsZXN0b25lNjA5NTgxOA==',
#    'number': 80,
#    'title': '1.3',
#    'description': '',
#    'creator': {'login': 'jreback',
#     'id': 953992,
#     'node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#     'avatar_url': 'https://avatars2.githubusercontent.com/u/953992?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jreback',
#     'html_url': 'https://github.com/jreback',
#     'followers_url': 'https://api.github.com/users/jreback/followers',
#     'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jreback/orgs',
#     'repos_url': 'https://api.github.com/users/jreback/repos',
#     'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jreback/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 77,
#    'closed_issues': 461,
#    'state': 'open',
#    'created_at': '2020-11-11T19:05:43Z',
#    'updated_at': '2021-01-11T14:52:28Z',
#    'due_on': '2021-05-31T07:00:00Z',
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2021-01-11T14:13:46Z',
#   'updated_at': '2021-01-11T14:14:02Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/39107',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/39107',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/39107.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/39107.patch'},
#   'body': '- [ ] closes #37134\r\n- [ ] tests added / passed\r\n- [ ] Ensure all linting tests pass, see [here](https://pandas.pydata.org/pandas-docs/dev/development/contributing.html#code-standards) for how to run them\r\n- [ ] whatsnew entry\r\n',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39104',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39104/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39104/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39104/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/39104',
#   'id': 783371878,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NTUyNzQyMzA1',
#   'number': 39104,
#   'title': 'TYP: fix mypy errors in pandas/core/arraylike.py',
#   'user': {'login': 'ivanovmg',
#    'id': 41443370,
#    'node_id': 'MDQ6VXNlcjQxNDQzMzcw',
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/41443370?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ivanovmg',
#    'html_url': 'https://github.com/ivanovmg',
#    'followers_url': 'https://api.github.com/users/ivanovmg/followers',
#    'following_url': 'https://api.github.com/users/ivanovmg/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/ivanovmg/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/ivanovmg/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/ivanovmg/subscriptions',
#    'organizations_url': 'https://api.github.com/users/ivanovmg/orgs',
#    'repos_url': 'https://api.github.com/users/ivanovmg/repos',
#    'events_url': 'https://api.github.com/users/ivanovmg/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/ivanovmg/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 1280988427,
#     'node_id': 'MDU6TGFiZWwxMjgwOTg4NDI3',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Typing',
#     'name': 'Typing',
#     'color': 'ea91a4',
#     'default': False,
#     'description': 'mypy type annotations'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/80',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/80',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/80/labels',
#    'id': 6095818,
#    'node_id': 'MDk6TWlsZXN0b25lNjA5NTgxOA==',
#    'number': 80,
#    'title': '1.3',
#    'description': '',
#    'creator': {'login': 'jreback',
#     'id': 953992,
#     'node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#     'avatar_url': 'https://avatars2.githubusercontent.com/u/953992?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jreback',
#     'html_url': 'https://github.com/jreback',
#     'followers_url': 'https://api.github.com/users/jreback/followers',
#     'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jreback/orgs',
#     'repos_url': 'https://api.github.com/users/jreback/repos',
#     'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jreback/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 77,
#    'closed_issues': 461,
#    'state': 'open',
#    'created_at': '2020-11-11T19:05:43Z',
#    'updated_at': '2021-01-11T14:52:28Z',
#    'due_on': '2021-05-31T07:00:00Z',
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2021-01-11T13:29:06Z',
#   'updated_at': '2021-01-11T13:58:15Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/39104',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/39104',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/39104.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/39104.patch'},
#   'body': '- [ ] xref #37715\r\n- [ ] tests added / passed\r\n- [ ] Ensure all linting tests pass, see [here](https://pandas.pydata.org/pandas-docs/dev/development/contributing.html#code-standards) for how to run them\r\n- [ ] whatsnew entry\r\n\r\nHandle ignored mypy errors in ``pandas/core/arraylike.py``.',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39103',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39103/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39103/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39103/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/39103',
#   'id': 783355986,
#   'node_id': 'MDU6SXNzdWU3ODMzNTU5ODY=',
#   'number': 39103,
#   'title': "BUG: GroupBy dictionary aggregation raises ValueError when 'as_index=False'",
#   'user': {'login': 'dchigarev',
#    'id': 62142979,
#    'node_id': 'MDQ6VXNlcjYyMTQyOTc5',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/62142979?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dchigarev',
#    'html_url': 'https://github.com/dchigarev',
#    'followers_url': 'https://api.github.com/users/dchigarev/followers',
#    'following_url': 'https://api.github.com/users/dchigarev/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/dchigarev/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/dchigarev/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/dchigarev/subscriptions',
#    'organizations_url': 'https://api.github.com/users/dchigarev/orgs',
#    'repos_url': 'https://api.github.com/users/dchigarev/repos',
#    'events_url': 'https://api.github.com/users/dchigarev/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/dchigarev/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-01-11T13:06:46Z',
#   'updated_at': '2021-01-11T13:09:39Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '- [x] I have checked that this issue has not already been reported.\r\n\r\n- [x] I have confirmed this bug exists on the latest version of pandas.\r\n\r\n- [ ] (optional) I have confirmed this bug exists on the master branch of pandas.\r\n\r\n---\r\n\r\n#### Code Sample, a copy-pastable example\r\n\r\n```python\r\nimport numpy as np\r\nimport pandas\r\n\r\n# Could be any data with MultiIndex columns\r\ndata = {(f"col{i}", f"level-{i % 2}"): np.arange(5) for i in range(5)}\r\ndf = pandas.DataFrame(data)\r\n\r\nby = df.columns[0]\r\nagg_col = df.columns[1]\r\n\r\nagg_dict = {agg_col: ["min", "max"]}\r\ndf.groupby(by, as_index=False).agg(func=agg_dict)  # ValueError\r\n\r\n```\r\n\r\n<details><summary>Traceback</summary>\r\n\r\n```\r\nTraceback (most recent call last):\r\n  File "../exp.py", line 12, in <module>\r\n    df.groupby(by, as_index=False).agg(func=agg_dict)  # ValueError\r\n  File "/localdisk/dchigare/miniconda3/envs/modin_tests/lib/python3.7/site-packages/pandas/core/groupby/generic.py", line 990, in aggregate\r\n    self._insert_inaxis_grouper_inplace(result)\r\n  File "/localdisk/dchigare/miniconda3/envs/modin_tests/lib/python3.7/site-packages/pandas/core/groupby/generic.py", line 1614, in _insert_inaxis_grouper_inplace\r\n    result.insert(0, name, lev)\r\n  File "/localdisk/dchigare/miniconda3/envs/modin_tests/lib/python3.7/site-packages/pandas/core/frame.py", line 3760, in insert\r\n    self._mgr.insert(loc, column, value, allow_duplicates=allow_duplicates)\r\n  File "/localdisk/dchigare/miniconda3/envs/modin_tests/lib/python3.7/site-packages/pandas/core/internals/managers.py", line 1197, in insert\r\n    new_axis = self.items.insert(loc, item)\r\n  File "/localdisk/dchigare/miniconda3/envs/modin_tests/lib/python3.7/site-packages/pandas/core/indexes/multi.py", line 3801, in insert\r\n    item = self._validate_fill_value(item)\r\n  File "/localdisk/dchigare/miniconda3/envs/modin_tests/lib/python3.7/site-packages/pandas/core/indexes/multi.py", line 3784, in _validate_fill_value\r\n    raise ValueError("Item must have length equal to number of levels.")\r\nValueError: Item must have length equal to number of levels.\r\n```\r\n\r\n</details>\r\n\r\n#### Problem description\r\n\r\nWhen we specify an aggregation function via list, pandas adds a new level with function name to the columns of the resulted frame:\r\n```python\r\n>>> df\r\n   col0  col1\r\n0     0     0\r\n>>> df.groupby("col0").agg({"col1": ["max"]})\r\n     col1\r\n      max\r\ncol0\r\n0       0\r\n```\r\nIn the result, the number of levels in the index which represents grouper and columns is different, which causes some problems in [`_insert_inaxis_grouper_inplace`](https://github.com/pandas-dev/pandas/blob/3bd3d1ec253a8a18ac951511820eb970f62baaed/pandas/core/groupby/generic.py#L1610-L1621). When we\'re trying to insert MultiIndex grouper inside the resulted frame, but their `nlevels` is different, `pandas.DataFrame.insert` raises a `ValueError` because of it. \r\n\r\nFilling mismatched levels with an empty string (like pandas already does when inserted value don\'t have MultiIndex columns) will probably solve this issue\r\n```python\r\n>>> df.groupby("col0", as_index=False).agg({"col1": ["max"]}).columns\r\nMultiIndex([(\'col0\',    \'\'),\r\n            (\'col1\', \'max\')],\r\n           )\r\n```\r\n\r\n#### Output of ``pd.show_versions()``\r\n\r\n<details>\r\n\r\n```\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 3e89b4c4b1580aa890023fc550774e63d499da25\r\npython           : 3.7.7.final.0\r\npython-bits      : 64\r\nOS               : Linux\r\nOS-release       : 4.15.0-50-generic\r\nVersion          : #54-Ubuntu SMP Mon May 6 18:46:08 UTC 2019\r\nmachine          : x86_64\r\nprocessor        : x86_64\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : en_US.UTF-8\r\nLOCALE           : en_US.UTF-8\r\n\r\npandas           : 1.2.0\r\nnumpy            : 1.19.0\r\npytz             : 2020.1\r\ndateut ...
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39102',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39102/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39102/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39102/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/39102',
#   'id': 783352257,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NTUyNzI1ODU5',
#   'number': 39102,
#   'title': 'MOVE: describe to pandas/core/describe.py',
#   'user': {'login': 'ivanovmg',
#    'id': 41443370,
#    'node_id': 'MDQ6VXNlcjQxNDQzMzcw',
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/41443370?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ivanovmg',
#    'html_url': 'https://github.com/ivanovmg',
#    'followers_url': 'https://api.github.com/users/ivanovmg/followers',
#    'following_url': 'https://api.github.com/users/ivanovmg/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/ivanovmg/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/ivanovmg/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/ivanovmg/subscriptions',
#    'organizations_url': 'https://api.github.com/users/ivanovmg/orgs',
#    'repos_url': 'https://api.github.com/users/ivanovmg/repos',
#    'events_url': 'https://api.github.com/users/ivanovmg/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/ivanovmg/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 127681,
#     'node_id': 'MDU6TGFiZWwxMjc2ODE=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Refactor',
#     'name': 'Refactor',
#     'color': 'FCE94F',
#     'default': False,
#     'description': 'Internal refactoring of code'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/80',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/80',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/80/labels',
#    'id': 6095818,
#    'node_id': 'MDk6TWlsZXN0b25lNjA5NTgxOA==',
#    'number': 80,
#    'title': '1.3',
#    'description': '',
#    'creator': {'login': 'jreback',
#     'id': 953992,
#     'node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#     'avatar_url': 'https://avatars2.githubusercontent.com/u/953992?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jreback',
#     'html_url': 'https://github.com/jreback',
#     'followers_url': 'https://api.github.com/users/jreback/followers',
#     'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jreback/orgs',
#     'repos_url': 'https://api.github.com/users/jreback/repos',
#     'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jreback/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 77,
#    'closed_issues': 461,
#    'state': 'open',
#    'created_at': '2020-11-11T19:05:43Z',
#    'updated_at': '2021-01-11T14:52:28Z',
#    'due_on': '2021-05-31T07:00:00Z',
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2021-01-11T13:01:20Z',
#   'updated_at': '2021-01-11T14:42:30Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/39102',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/39102',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/39102.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/39102.patch'},
#   'body': '- [ ] closes #xxxx\r\n- [ ] tests added / passed\r\n- [ ] Ensure all linting tests pass, see [here](https://pandas.pydata.org/pandas-docs/dev/development/contributing.html#code-standards) for how to run them\r\n- [ ] whatsnew entry\r\n\r\nMove ``describe`` functionality to a separate module and prepare for the further refactor/simplification (xref #36833).\r\n\r\n - Created new module ``pandas/core/describe.py``\r\n - Delegate the functionality of ``NDFrame.describe`` to function ``describe_ndframe`` in the new module',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39100',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39100/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39100/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39100/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/39100',
#   'id': 783325788,
#   'node_id': 'MDU6SXNzdWU3ODMzMjU3ODg=',
#   'number': 39100,
#   'title': "BUG: merge by multiindex doesn't work correctly",
#   'user': {'login': 'pgagarinov',
#    'id': 4868370,
#    'node_id': 'MDQ6VXNlcjQ4NjgzNzA=',
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/4868370?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/pgagarinov',
#    'html_url': 'https://github.com/pgagarinov',
#    'followers_url': 'https://api.github.com/users/pgagarinov/followers',
#    'following_url': 'https://api.github.com/users/pgagarinov/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/pgagarinov/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/pgagarinov/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/pgagarinov/subscriptions',
#    'organizations_url': 'https://api.github.com/users/pgagarinov/orgs',
#    'repos_url': 'https://api.github.com/users/pgagarinov/repos',
#    'events_url': 'https://api.github.com/users/pgagarinov/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/pgagarinov/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-01-11T12:20:29Z',
#   'updated_at': '2021-01-11T13:49:31Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '- [x] I have checked that this issue has not already been reported.\r\n\r\n- [x] I have confirmed this bug exists on the latest version of pandas.\r\n\r\n- [ ] (optional) I have confirmed this bug exists on the master branch of pandas.\r\n\r\n#### Code Sample, a copy-pastable example\r\n\r\n```python\r\nimport pandas as pd\r\nimport numpy as np\r\n\r\na_dict = {\'val-single-trial-LitPrettyBoringMNIST_f1\': {(0,\r\n   \'Train/Val\',\r\n   (\'train\', \'val\')): 0.1189,\r\n  (1, \'Train/Val\', (\'train\', \'val\')): 0.1373,\r\n  (2, \'Train/Val\', (\'train\', \'val\')): 0.3173,\r\n  (2, \'Reval\', (\'reval\',)): 0.3173,\r\n  (2, \'Test\', (\'test\',)): 0.3173}}\r\n\r\na_df = pd.DataFrame(a_dict)\r\n\r\na_df.index = a_df.index.set_names([\'epoch\', \'stage\', \'stage-list\'])\r\n\r\na_df = a_df.iloc[[0,1,4,2, 3],:]\r\n\r\nb_dict = {\'reval-hyper-opt-LitPrettyBoringMNIST_f1\': {(0, \'Reval\', (\'reval\',)): 0.0317,\r\n  (0, \'Test\', (\'test\',)): np.nan}}\r\n\r\nb_df = pd.DataFrame(b_dict)\r\n\r\nb_df.index = b_df.index.set_names([\'epoch\', \'stage\', \'stage-list\'])\r\n\r\n\r\nbad_merge_df = a_df.merge(b_df, how=\'outer\', left_index=True, right_index=True)\r\n\r\ngood_merge_df = a_df.merge(b_df, how=\'outer\', on=[\'epoch\', \'stage\', \'stage-list\'])\r\n\r\n```\r\nSame example on calab\r\nhttps://colab.research.google.com/drive/1kz2ddulSuC4o3w580wk1iiiU8KJPll1U#scrollTo=2ZCn944CXDRG\r\n\r\n\r\n#### Problem description\r\nbad_merge_df contains a lot of nans:\r\n\r\n<img width="810" alt="image" src="https://user-images.githubusercontent.com/4868370/104181719-5368dd00-5420-11eb-8fdd-6de500c02d25.png">\r\n\r\n#### Expected Output\r\n\r\n<img width="840" alt="image" src="https://user-images.githubusercontent.com/4868370/104181775-68457080-5420-11eb-9c34-45af8797f218.png">\r\n\r\n\r\n#### Output of ``pd.show_versions()``\r\n\r\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 3e89b4c4b1580aa890023fc550774e63d499da25\r\npython           : 3.8.5.final.0\r\npython-bits      : 64\r\nOS               : Linux\r\nOS-release       : 5.4.85-1-MANJARO\r\nVersion          : #1 SMP PREEMPT Mon Dec 21 21:38:53 UTC 2020\r\nmachine          : x86_64\r\nprocessor        : \r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : en.UTF-8\r\nLOCALE           : None.None\r\n\r\npandas           : 1.2.0\r\nnumpy            : 1.19.5\r\npytz             : 2020.5\r\ndateutil         : 2.8.1\r\npip              : 20.3.3\r\nsetuptools       : 49.6.0.post20210108\r\nCython           : None\r\npytest           : 6.2.1\r\nhypothesis       : None\r\nsphinx           : None\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : None\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : 2.11.2\r\nIPython          : 7.19.0\r\npandas_datareader: None\r\nbs4              : None\r\nbottleneck       : None\r\nfsspec           : 0.8.5\r\nfastparquet      : None\r\ngcsfs            : None\r\nmatplotlib       : 3.3.3\r\nnumexpr          : None\r\nodfpy            : None\r\nopenpyxl         : None\r\npandas_gbq       : None\r\npyarrow          : 2.0.0\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : 1.6.0\r\nsqlalchemy       : 1.3.22\r\ntables           : None\r\ntabulate         : 0.8.7\r\nxarray           : None\r\nxlrd             : None\r\nxlwt             : None\r\nnumba            : 0.52.0\r\n\r\n</details>\r\n',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39098',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39098/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39098/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39098/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/39098',
#   'id': 783076118,
#   'node_id': 'MDU6SXNzdWU3ODMwNzYxMTg=',
#   'number': 39098,
#   'title': 'BUG: Groupby agg on decimal,json extension arrays changes dtype to object',
#   'user': {'login': 'BryanCutler',
#    'id': 4534389,
#    'node_id': 'MDQ6VXNlcjQ1MzQzODk=',
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/4534389?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/BryanCutler',
#    'html_url': 'https://github.com/BryanCutler',
#    'followers_url': 'https://api.github.com/users/BryanCutler/followers',
#    'following_url': 'https://api.github.com/users/BryanCutler/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/BryanCutler/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/BryanCutler/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/BryanCutler/subscriptions',
#    'organizations_url': 'https://api.github.com/users/BryanCutler/orgs',
#    'repos_url': 'https://api.github.com/users/BryanCutler/repos',
#    'events_url': 'https://api.github.com/users/BryanCutler/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/BryanCutler/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2021-01-11T05:30:39Z',
#   'updated_at': '2021-01-11T05:31:47Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'body': '- [X] I have checked that this issue has not already been reported.\r\n\r\n- [X] I have confirmed this bug exists on the latest version of pandas.\r\n\r\n- [X] (optional) I have confirmed this bug exists on the master branch of pandas.\r\n\r\n---\r\n\r\n#### Code Sample, a copy-pastable example\r\n\r\n```python\r\nimport decimal\r\nfrom pandas.tests.extension.decimal import DecimalArray\r\nimport pandas as pd\r\n\r\nb = decimal.Decimal("1.0")\r\na = decimal.Decimal("0.0")\r\nc = decimal.Decimal("2.0")\r\nna = decimal.Decimal("NaN")\r\n\r\ndf = pd.DataFrame({\r\n    \'key\': [1, 1, 2, 2, 3, 3, 1, 4], \r\n    \'val\': DecimalArray([b, b, na, na, a, a, b, c])\r\n})\r\n\r\nresult = df.groupby("key").agg({\'val\': \'first\'})\r\n\r\nprint(result[\'val\').dtype)\r\n# object\r\n```\r\n\r\n#### Problem description\r\n\r\nWhen performing a `groupby().agg()` on extension arrays `DecimalArray` or `JsonArray`, if a NULL value is present, the resulting aggregation will be converted to an `object` dtype.\r\n\r\n#### Expected Output\r\n\r\nResulting series should be the same dtype as the input array, and any NULL values should be as defined in the extension dtype.\r\n\r\n\r\n#### Output of ``pd.show_versions()``\r\n\r\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 1c296b20f7ab9822dacaa894afecd960bb43fc47\r\npython           : 3.8.6.final.0\r\npython-bits      : 64\r\nOS               : Linux\r\nOS-release       : 5.4.0-58-generic\r\nVersion          : #64-Ubuntu SMP Wed Dec 9 08:16:25 UTC 2020\r\nmachine          : x86_64\r\nprocessor        : x86_64\r\nbyteorder        : little\r\nLC_ALL           : C.UTF-8\r\nLANG             : C.UTF-8\r\nLOCALE           : en_US.UTF-8\r\n\r\npandas           : 1.3.0.dev0+357.g1c296b20f.dirty\r\nnumpy            : 1.19.4\r\npytz             : 2020.4\r\ndateutil         : 2.8.1\r\npip              : 20.0.2\r\nsetuptools       : 49.6.0.post20201009\r\nCython           : 0.29.21\r\npytest           : 6.1.2\r\nhypothesis       : 5.41.5\r\nsphinx           : 3.3.1\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : 1.3.7\r\nlxml.etree       : 4.6.2\r\nhtml5lib         : 1.1\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : 2.11.2\r\nIPython          : 7.19.0\r\npandas_datareader: None\r\nbs4              : 4.9.3\r\nbottleneck       : 1.3.2\r\nfsspec           : 0.8.4\r\nfastparquet      : 0.4.1\r\ngcsfs            : 0.7.1\r\nmatplotlib       : 3.3.3\r\nnumexpr          : 2.7.1\r\nodfpy            : None\r\nopenpyxl         : 3.0.5\r\npandas_gbq       : None\r\npyarrow          : 2.0.0\r\npyxlsb           : None\r\ns3fs             : 0.4.2\r\nscipy            : 1.5.3\r\nsqlalchemy       : 1.3.20\r\ntables           : 3.6.1\r\ntabulate         : 0.8.7\r\nxarray           : 0.16.2\r\nxlrd             : 1.2.0\r\nxlwt             : 1.3.0\r\nnumba            : 0.52.0\r\n\r\n</details>\r\n',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39097',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39097/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39097/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39097/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/39097',
#   'id': 782938704,
#   'node_id': 'MDU6SXNzdWU3ODI5Mzg3MDQ=',
#   'number': 39097,
#   'title': 'BUG: DateOffset applied to DatetimeIndex losing freq starting in v1.1.0',
#   'user': {'login': 'bexer',
#    'id': 2894002,
#    'node_id': 'MDQ6VXNlcjI4OTQwMDI=',
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/2894002?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/bexer',
#    'html_url': 'https://github.com/bexer',
#    'followers_url': 'https://api.github.com/users/bexer/followers',
#    'following_url': 'https://api.github.com/users/bexer/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/bexer/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/bexer/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/bexer/subscriptions',
#    'organizations_url': 'https://api.github.com/users/bexer/orgs',
#    'repos_url': 'https://api.github.com/users/bexer/repos',
#    'events_url': 'https://api.github.com/users/bexer/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/bexer/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-01-11T00:01:58Z',
#   'updated_at': '2021-01-11T00:01:58Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '- [x] I have checked that this issue has not already been reported.\r\n\r\n- [x] I have confirmed this bug exists on the latest version of pandas.\r\n\r\n- [ ] (optional) I have confirmed this bug exists on the master branch of pandas.\r\n\r\n---\r\n\r\n#### Code Sample, a copy-pastable example\r\n\r\n```python\r\nimport pandas as pd\r\n\r\ndtsa = pd.date_range(\'1998\', periods = 3, freq = \'A\')\r\ns1 = pd.Series([4,5,6], index=dtsa)\r\ns1.index\r\n# DatetimeIndex([\'1998-12-31\', \'1999-12-31\', \'2000-12-31\'], dtype=\'datetime64[ns]\', freq=\'A-DEC\')\r\n\r\ni1 = s1.index + pd.DateOffset(years=-1, days=1)\r\ni1\r\n# DatetimeIndex([\'1998-01-01\', \'1999-01-01\', \'2000-01-01\'], dtype=\'datetime64[ns]\', freq=None)\r\n```\r\n\r\n#### Problem description\r\n\r\nI expected **i1** to have the frequency "AS-JAN" instead of None. This behavior existed prior to version 1.1.0. For example, in 1.0.5 the output of the same commands is:\r\n```python\r\n> DatetimeIndex([\'1998-01-01\', \'1999-01-01\', \'2000-01-01\'], dtype=\'datetime64[ns]\', freq=\'AS-JAN\')\r\n```\r\n\r\n#### Expected Output\r\n\r\n```python\r\n> DatetimeIndex([\'1998-01-01\', \'1999-01-01\', \'2000-01-01\'], dtype=\'datetime64[ns]\', freq=\'AS-JAN\')\r\n```\r\n\r\n#### Output of ``pd.show_versions()``\r\n\r\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : d9fff2792bf16178d4e450fe7384244e50635733\r\npython           : 3.8.0.final.0\r\npython-bits      : 64\r\nOS               : Windows\r\nOS-release       : 10\r\nVersion          : 10.0.17134\r\nmachine          : AMD64\r\nprocessor        : Intel64 Family 6 Model 94 Stepping 3, GenuineIntel\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : None\r\nLOCALE           : English_United States.1252\r\n\r\npandas           : 1.1.0\r\nnumpy            : 1.19.2\r\npytz             : 2020.5\r\ndateutil         : 2.8.1\r\npip              : 20.3.3\r\nsetuptools       : 51.0.0.post20201207\r\nCython           : None\r\npytest           : None\r\nhypothesis       : None\r\nsphinx           : None\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : None\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : 2.11.2\r\nIPython          : 7.19.0\r\npandas_datareader: None\r\nbs4              : None\r\nbottleneck       : None\r\nfsspec           : None\r\nfastparquet      : None\r\ngcsfs            : None\r\nmatplotlib       : None\r\nnumexpr          : None\r\nodfpy            : None\r\nopenpyxl         : None\r\npandas_gbq       : None\r\npyarrow          : None\r\npytables         : None\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : None\r\nsqlalchemy       : None\r\ntables           : None\r\ntabulate         : None\r\nxarray           : None\r\nxlrd             : None\r\nxlwt             : None\r\nnumba            : None\r\n\r\n</details>\r\n',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39096',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39096/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39096/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39096/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/39096',
#   'id': 782922944,
#   'node_id': 'MDU6SXNzdWU3ODI5MjI5NDQ=',
#   'number': 39096,
#   'title': 'TST/COMPAT: test memory usage failed on macOS after change pytest-xdist -dist to `no`',
#   'user': {'login': 'fangchenli',
#    'id': 7614606,
#    'node_id': 'MDQ6VXNlcjc2MTQ2MDY=',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/7614606?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/fangchenli',
#    'html_url': 'https://github.com/fangchenli',
#    'followers_url': 'https://api.github.com/users/fangchenli/followers',
#    'following_url': 'https://api.github.com/users/fangchenli/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/fangchenli/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/fangchenli/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/fangchenli/subscriptions',
#    'organizations_url': 'https://api.github.com/users/fangchenli/orgs',
#    'repos_url': 'https://api.github.com/users/fangchenli/repos',
#    'events_url': 'https://api.github.com/users/fangchenli/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/fangchenli/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76865106,
#     'node_id': 'MDU6TGFiZWw3Njg2NTEwNg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Compat',
#     'name': 'Compat',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Related to pandas compatibility with other libraries'},
#    {'id': 127685,
#     'node_id': 'MDU6TGFiZWwxMjc2ODU=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Testing',
#     'name': 'Testing',
#     'color': 'C4A000',
#     'default': False,
#     'description': 'Custom testing functions or related to the test suite'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-01-10T22:28:36Z',
#   'updated_at': '2021-01-10T22:29:17Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'body': 'In #38905, I changed the distribution algorithm of pytest-xdist to `no` from `loadfile`.  And the test `pandas/tests/base/test_misc.py:test_memory_usage` failed on macOS.\r\n\r\n```bash\r\nindex_or_series_obj = Series([], Name: a, dtype: float64)\r\n\r\n    @pytest.mark.skipif(PYPY, reason="not relevant for PyPy")\r\n    def test_memory_usage(index_or_series_obj):\r\n        obj = index_or_series_obj\r\n    \r\n        res = obj.memory_usage()\r\n        res_deep = obj.memory_usage(deep=True)\r\n    \r\n        is_object = is_object_dtype(obj) or (\r\n            isinstance(obj, Series) and is_object_dtype(obj.index)\r\n        )\r\n        is_categorical = is_categorical_dtype(obj.dtype) or (\r\n            isinstance(obj, Series) and is_categorical_dtype(obj.index.dtype)\r\n        )\r\n    \r\n        if len(obj) == 0:\r\n            if isinstance(obj, Index):\r\n                expected = 0\r\n            else:\r\n                expected = 108 if IS64 else 64\r\n>           assert res_deep == res == expected\r\nE           assert 0 == 108\r\n```\r\n',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39094',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39094/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39094/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39094/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/39094',
#   'id': 782900078,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NTUyMzQyNzUy',
#   'number': 39094,
#   'title': 'REF: implement dtypes.cast.can_hold_element',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
# ...
#     'site_admin': False},
#    'open_issues': 77,
#    'closed_issues': 461,
#    'state': 'open',
#    'created_at': '2020-11-11T19:05:43Z',
#    'updated_at': '2021-01-11T14:52:28Z',
#    'due_on': '2021-05-31T07:00:00Z',
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2021-01-09T14:25:09Z',
#   'updated_at': '2021-01-10T11:09:39Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/39059',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/39059',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/39059.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/39059.patch'},
#   'body': 'xref #37715',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39053',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39053/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39053/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39053/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/39053',
#   'id': 782594598,
#   'node_id': 'MDU6SXNzdWU3ODI1OTQ1OTg=',
#   'number': 39053,
#   'title': 'ENH: Please provide "universal2" wheels for macOS',
#   'user': {'login': 'ronaldoussoren',
#    'id': 713966,
#    'node_id': 'MDQ6VXNlcjcxMzk2Ng==',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/713966?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ronaldoussoren',
#    'html_url': 'https://github.com/ronaldoussoren',
#    'followers_url': 'https://api.github.com/users/ronaldoussoren/followers',
#    'following_url': 'https://api.github.com/users/ronaldoussoren/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/ronaldoussoren/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/ronaldoussoren/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/ronaldoussoren/subscriptions',
#    'organizations_url': 'https://api.github.com/users/ronaldoussoren/orgs',
#    'repos_url': 'https://api.github.com/users/ronaldoussoren/repos',
#    'events_url': 'https://api.github.com/users/ronaldoussoren/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/ronaldoussoren/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76812,
#     'node_id': 'MDU6TGFiZWw3NjgxMg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Enhancement',
#     'name': 'Enhancement',
#     'color': '4E9A06',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 3,
#   'created_at': '2021-01-09T12:08:52Z',
#   'updated_at': '2021-01-11T07:55:12Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '#### Is your feature request related to a problem?\r\n\r\nThere is a, currently formally experimental, "universal2" installer for Python on www.python.org. This natively supports both x86_64 (macOS 10.9 or later) and arm64 (macOS 11.0 or later).   Using pandas with this installer currently requires building pandas from source, not from a binary wheel.\r\n\r\n#### Describe the solution you\'d like\r\n\r\nA binary wheel on PyPI for the "universal2" installer, next to the "x86_64" wheel there already is.\r\n\r\nIn the longer run I\'d love to see only "universal2" wheels and no "x86_64" wheels, but that at the very least requires time for   support in the packaging system to further mature (support for "universal2" in pip and wheel is pretty new at this point).\r\n',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39051',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39051/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39051/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39051/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/39051',
#   'id': 782561585,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NTUyMDk3Mzky',
#   'number': 39051,
#   'title': 'ENH: try to preserve the dtype on combine_first for the case where the two DataFrame objects have the same columns',
#   'user': {'login': 'danielhrisca',
#    'id': 20952040,
#    'node_id': 'MDQ6VXNlcjIwOTUyMDQw',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/20952040?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/danielhrisca',
#    'html_url': 'https://github.com/danielhrisca',
#    'followers_url': 'https://api.github.com/users/danielhrisca/followers',
#    'following_url': 'https://api.github.com/users/danielhrisca/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/danielhrisca/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/danielhrisca/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/danielhrisca/subscriptions',
#    'organizations_url': 'https://api.github.com/users/danielhrisca/orgs',
#    'repos_url': 'https://api.github.com/users/danielhrisca/repos',
#    'events_url': 'https://api.github.com/users/danielhrisca/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/danielhrisca/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 31404521,
#     'node_id': 'MDU6TGFiZWwzMTQwNDUyMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Dtypes',
#     'name': 'Dtypes',
#     'color': 'e102d8',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2021-01-09T08:27:59Z',
#   'updated_at': '2021-01-11T15:22:11Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/39051',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/39051',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/39051.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/39051.patch'},
#   'body': '…e two DataFrame objects have the same columns\r\n\r\n- [ ] closes #7509 \r\n- [ ] tests added / passed\r\n- [ ] Ensure all linting tests pass, see [here](https://pandas.pydata.org/pandas-docs/dev/development/contributing.html#code-standards) for how to run them\r\n- [ ] whatsnew entry\r\n',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39047',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39047/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39047/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39047/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/39047',
#   'id': 782494701,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NTUyMDQwOTk5',
#   'number': 39047,
#   'title': 'TST: extend check for leaked files',
#   'user': {'login': 'twoertwein',
#    'id': 6618166,
#    'node_id': 'MDQ6VXNlcjY2MTgxNjY=',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/6618166?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/twoertwein',
#    'html_url': 'https://github.com/twoertwein',
#    'followers_url': 'https://api.github.com/users/twoertwein/followers',
#    'following_url': 'https://api.github.com/users/twoertwein/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/twoertwein/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/twoertwein/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/twoertwein/subscriptions',
#    'organizations_url': 'https://api.github.com/users/twoertwein/orgs',
#    'repos_url': 'https://api.github.com/users/twoertwein/repos',
#    'events_url': 'https://api.github.com/users/twoertwein/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/twoertwein/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 127685,
#     'node_id': 'MDU6TGFiZWwxMjc2ODU=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Testing',
#     'name': 'Testing',
#     'color': 'C4A000',
#     'default': False,
#     'description': 'Custom testing functions or related to the test suite'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2021-01-09T02:31:51Z',
#   'updated_at': '2021-01-11T01:02:17Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/39047',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/39047',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/39047.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/39047.patch'},
#   'body': "Use `ResourceWarning`s as indicators of leaked files. I left the `psutil`-based check for leaked files.\r\n\r\nI enabled the check for leaked files for all io tests.\r\n\r\nExisting warnings:\r\n- [ ]  all excel functions using pyxlsb: fixed by https://github.com/willtrnr/pyxlsb/pull/32 and this PR\r\n- [ ]  TestS3.test_write_s3_csv_fails: unclosed `ssl.SSLSocket`\r\n- [ ]  test_skip_row_with_newline_and_quote: multiple unclosed `ssl.SSLSocket` and `socket.socket`\r\n- [ ]  TestSQLApiConn.test_*: unclosed `asyncio.sslproto._SSLProtocolTransport`\r\n- [ ]  TestStata.test_* on windwos:  `ResourceWarning('This save was not successful but C:\\\\Users\\\\VSSADM~1\\\\AppData\\\\Local\\\\Temp\\\\tmpbhavxy1v could not be deleted.  This file is not valid.')`\r\n- [ ] test_server_and_default_headers on windows: unclosed `asyncio.sslproto._SSLProtocolTransport`",
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39044',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39044/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39044/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39044/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/39044',
#   'id': 782435460,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NTUxOTkyNzgy',
#   'number': 39044,
#   'title': 'BUG/API: make setitem-inplace preserve dtype when possible with PandasArray, IntegerArray, FloatingArray',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-01-08T22:30:49Z',
#   'updated_at': '2021-01-09T23:28:27Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/39044',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/39044',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/39044.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/39044.patch'},
#   'body': '- [ ] closes #xxxx\r\n- [x] tests added / passed\r\n- [x] Ensure all linting tests pass, see [here](https://pandas.pydata.org/pandas-docs/dev/development/contributing.html#code-standards) for how to run them\r\n- [ ] whatsnew entry\r\n\r\nxref #38896 (doesn\'t close).  In general `df[:, "A"] = foo` tries to operate in-place before falling back to casting.  This makes sure we do that when `foo` is a `PandasArray`, `IntegerArray`, or `FloatingArray`\r\n\r\nI guess could/should do the same for BooleanArray\r\n',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39043',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39043/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39043/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39043/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/39043',
#   'id': 782430023,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NTUxOTg4NTA2',
#   'number': 39043,
#   'title': 'CI: use conda incubator in doc and benchmarks',
#   'user': {'login': 'fangchenli',
#    'id': 7614606,
#    'node_id': 'MDQ6VXNlcjc2MTQ2MDY=',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/7614606?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/fangchenli',
#    'html_url': 'https://github.com/fangchenli',
#    'followers_url': 'https://api.github.com/users/fangchenli/followers',
#    'following_url': 'https://api.github.com/users/fangchenli/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/fangchenli/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/fangchenli/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/fangchenli/subscriptions',
#    'organizations_url': 'https://api.github.com/users/fangchenli/orgs',
#    'repos_url': 'https://api.github.com/users/fangchenli/repos',
#    'events_url': 'https://api.github.com/users/fangchenli/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/fangchenli/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 48070600,
#     'node_id': 'MDU6TGFiZWw0ODA3MDYwMA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/CI',
#     'name': 'CI',
#     'color': 'a2bca7',
#     'default': False,
#     'description': 'Related to Continuous Integration'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-01-08T22:17:36Z',
#   'updated_at': '2021-01-11T02:28:32Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/39043',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/39043',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/39043.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/39043.patch'},
#   'body': 'The benchmark ci currently has the longest runtime. Using conda incubator would save about 6-8 min.\r\n',
#   'performed_via_github_app': None}]

# %%
data[0]
# Out:
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39109',
#  'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#  'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39109/labels{/name}',
#  'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39109/comments',
#  'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39109/events',
#  'html_url': 'https://github.com/pandas-dev/pandas/pull/39109',
#  'id': 783486912,
#  'node_id': 'MDExOlB1bGxSZXF1ZXN0NTUyODM4OTU1',
#  'number': 39109,
#  'title': 'DOC: NDFrame fillna method add use case',
#  'user': {'login': 'BeanNan',
#   'id': 40813941,
#   'node_id': 'MDQ6VXNlcjQwODEzOTQx',
#   'avatar_url': 'https://avatars2.githubusercontent.com/u/40813941?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/BeanNan',
#   'html_url': 'https://github.com/BeanNan',
#   'followers_url': 'https://api.github.com/users/BeanNan/followers',
#   'following_url': 'https://api.github.com/users/BeanNan/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/BeanNan/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/BeanNan/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/BeanNan/subscriptions',
#   'organizations_url': 'https://api.github.com/users/BeanNan/orgs',
#   'repos_url': 'https://api.github.com/users/BeanNan/repos',
#   'events_url': 'https://api.github.com/users/BeanNan/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/BeanNan/received_events',
#   'type': 'User',
#   'site_admin': False},
#  'labels': [],
#  'state': 'open',
#  'locked': False,
#  'assignee': None,
#  'assignees': [],
#  'milestone': None,
#  'comments': 0,
#  'created_at': '2021-01-11T15:49:45Z',
#  'updated_at': '2021-01-11T15:49:45Z',
#  'closed_at': None,
#  'author_association': 'CONTRIBUTOR',
#  'active_lock_reason': None,
#  'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/39109',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/39109',
#   'diff_url': 'https://github.com/pandas-dev/pandas/pull/39109.diff',
#   'patch_url': 'https://github.com/pandas-dev/pandas/pull/39109.patch'},
#  'body': '- [x] closes #38917 \r\n- [ ] tests added / passed\r\n- [ ] Ensure all linting tests pass, see [here](https://pandas.pydata.org/pandas-docs/dev/development/contributing.html#code-standards) for how to run them\r\n- [ ] whatsnew entry\r\n\r\ncc @MarcoGorelli',
#  'performed_via_github_app': None}

# %%
type(data)
# Out:
# list

# %%
data[0]['updated_at']
# Out:
# '2021-01-11T15:49:45Z'

# %%
data
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39109',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39109/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39109/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39109/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/39109',
#   'id': 783486912,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NTUyODM4OTU1',
#   'number': 39109,
#   'title': 'DOC: NDFrame fillna method add use case',
#   'user': {'login': 'BeanNan',
#    'id': 40813941,
#    'node_id': 'MDQ6VXNlcjQwODEzOTQx',
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/40813941?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/BeanNan',
#    'html_url': 'https://github.com/BeanNan',
#    'followers_url': 'https://api.github.com/users/BeanNan/followers',
#    'following_url': 'https://api.github.com/users/BeanNan/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/BeanNan/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/BeanNan/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/BeanNan/subscriptions',
#    'organizations_url': 'https://api.github.com/users/BeanNan/orgs',
#    'repos_url': 'https://api.github.com/users/BeanNan/repos',
#    'events_url': 'https://api.github.com/users/BeanNan/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/BeanNan/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-01-11T15:49:45Z',
#   'updated_at': '2021-01-11T15:49:45Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/39109',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/39109',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/39109.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/39109.patch'},
#   'body': '- [x] closes #38917 \r\n- [ ] tests added / passed\r\n- [ ] Ensure all linting tests pass, see [here](https://pandas.pydata.org/pandas-docs/dev/development/contributing.html#code-standards) for how to run them\r\n- [ ] whatsnew entry\r\n\r\ncc @MarcoGorelli',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39108',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39108/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39108/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39108/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/39108',
#   'id': 783413847,
#   'node_id': 'MDU6SXNzdWU3ODM0MTM4NDc=',
#   'number': 39108,
#   'title': 'TYP: clean notations in the wrong place',
#   'user': {'login': 'jreback',
#    'id': 953992,
#    'node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/953992?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jreback',
#    'html_url': 'https://github.com/jreback',
#    'followers_url': 'https://api.github.com/users/jreback/followers',
#    'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jreback/orgs',
#    'repos_url': 'https://api.github.com/users/jreback/repos',
#    'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jreback/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 1280988427,
#     'node_id': 'MDU6TGFiZWwxMjgwOTg4NDI3',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Typing',
#     'name': 'Typing',
#     'color': 'ea91a4',
#     'default': False,
#     'description': 'mypy type annotations'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/80',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/80',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/80/labels',
#    'id': 6095818,
#    'node_id': 'MDk6TWlsZXN0b25lNjA5NTgxOA==',
#    'number': 80,
#    'title': '1.3',
#    'description': '',
#    'creator': {'login': 'jreback',
#     'id': 953992,
#     'node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#     'avatar_url': 'https://avatars2.githubusercontent.com/u/953992?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jreback',
#     'html_url': 'https://github.com/jreback',
#     'followers_url': 'https://api.github.com/users/jreback/followers',
#     'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jreback/orgs',
#     'repos_url': 'https://api.github.com/users/jreback/repos',
#     'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jreback/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 77,
#    'closed_issues': 461,
#    'state': 'open',
#    'created_at': '2020-11-11T19:05:43Z',
#    'updated_at': '2021-01-11T14:52:28Z',
#    'due_on': '2021-05-31T07:00:00Z',
#    'closed_at': None},
#   'comments': 2,
#   'created_at': '2021-01-11T14:25:42Z',
#   'updated_at': '2021-01-11T14:27:43Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'body': 'https://github.com/pandas-dev/pandas/blob/master/pandas/core/groupby/groupby.py#L1294\r\n\r\n```\r\n# To track operations that expand dimensions, like ohlc\r\nOutputFrameOrSeries = TypeVar("OutputFrameOrSeries", bound=NDFrame)\r\n```\r\n\r\nat the very least this should be in `pandas._typing`. puzzled why we need this at *all*, as this is the same as `FrameOrSeries`',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39107',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39107/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39107/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39107/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/39107',
#   'id': 783404734,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NTUyNzY5NjIz',
#   'number': 39107,
#   'title': 'TYP: replace Label alias from pandas._typing with Hashable',
#   'user': {'login': 'simonjayhawkins',
#    'id': 13159005,
#    'node_id': 'MDQ6VXNlcjEzMTU5MDA1',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/13159005?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/simonjayhawkins',
#    'html_url': 'https://github.com/simonjayhawkins',
#    'followers_url': 'https://api.github.com/users/simonjayhawkins/followers',
#    'following_url': 'https://api.github.com/users/simonjayhawkins/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/simonjayhawkins/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/simonjayhawkins/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/simonjayhawkins/subscriptions',
#    'organizations_url': 'https://api.github.com/users/simonjayhawkins/orgs',
#    'repos_url': 'https://api.github.com/users/simonjayhawkins/repos',
#    'events_url': 'https://api.github.com/users/simonjayhawkins/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/simonjayhawkins/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 1280988427,
#     'node_id': 'MDU6TGFiZWwxMjgwOTg4NDI3',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Typing',
#     'name': 'Typing',
#     'color': 'ea91a4',
#     'default': False,
#     'description': 'mypy type annotations'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/80',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/80',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/80/labels',
#    'id': 6095818,
#    'node_id': 'MDk6TWlsZXN0b25lNjA5NTgxOA==',
#    'number': 80,
#    'title': '1.3',
#    'description': '',
#    'creator': {'login': 'jreback',
#     'id': 953992,
#     'node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#     'avatar_url': 'https://avatars2.githubusercontent.com/u/953992?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jreback',
#     'html_url': 'https://github.com/jreback',
#     'followers_url': 'https://api.github.com/users/jreback/followers',
#     'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jreback/orgs',
#     'repos_url': 'https://api.github.com/users/jreback/repos',
#     'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jreback/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 77,
#    'closed_issues': 461,
#    'state': 'open',
#    'created_at': '2020-11-11T19:05:43Z',
#    'updated_at': '2021-01-11T14:52:28Z',
#    'due_on': '2021-05-31T07:00:00Z',
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2021-01-11T14:13:46Z',
#   'updated_at': '2021-01-11T14:14:02Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/39107',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/39107',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/39107.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/39107.patch'},
#   'body': '- [ ] closes #37134\r\n- [ ] tests added / passed\r\n- [ ] Ensure all linting tests pass, see [here](https://pandas.pydata.org/pandas-docs/dev/development/contributing.html#code-standards) for how to run them\r\n- [ ] whatsnew entry\r\n',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39104',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39104/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39104/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39104/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/39104',
#   'id': 783371878,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NTUyNzQyMzA1',
#   'number': 39104,
#   'title': 'TYP: fix mypy errors in pandas/core/arraylike.py',
#   'user': {'login': 'ivanovmg',
#    'id': 41443370,
#    'node_id': 'MDQ6VXNlcjQxNDQzMzcw',
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/41443370?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ivanovmg',
#    'html_url': 'https://github.com/ivanovmg',
#    'followers_url': 'https://api.github.com/users/ivanovmg/followers',
#    'following_url': 'https://api.github.com/users/ivanovmg/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/ivanovmg/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/ivanovmg/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/ivanovmg/subscriptions',
#    'organizations_url': 'https://api.github.com/users/ivanovmg/orgs',
#    'repos_url': 'https://api.github.com/users/ivanovmg/repos',
#    'events_url': 'https://api.github.com/users/ivanovmg/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/ivanovmg/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 1280988427,
#     'node_id': 'MDU6TGFiZWwxMjgwOTg4NDI3',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Typing',
#     'name': 'Typing',
#     'color': 'ea91a4',
#     'default': False,
#     'description': 'mypy type annotations'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/80',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/80',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/80/labels',
#    'id': 6095818,
#    'node_id': 'MDk6TWlsZXN0b25lNjA5NTgxOA==',
#    'number': 80,
#    'title': '1.3',
#    'description': '',
#    'creator': {'login': 'jreback',
#     'id': 953992,
#     'node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#     'avatar_url': 'https://avatars2.githubusercontent.com/u/953992?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jreback',
#     'html_url': 'https://github.com/jreback',
#     'followers_url': 'https://api.github.com/users/jreback/followers',
#     'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jreback/orgs',
#     'repos_url': 'https://api.github.com/users/jreback/repos',
#     'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jreback/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 77,
#    'closed_issues': 461,
#    'state': 'open',
#    'created_at': '2020-11-11T19:05:43Z',
#    'updated_at': '2021-01-11T14:52:28Z',
#    'due_on': '2021-05-31T07:00:00Z',
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2021-01-11T13:29:06Z',
#   'updated_at': '2021-01-11T13:58:15Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/39104',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/39104',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/39104.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/39104.patch'},
#   'body': '- [ ] xref #37715\r\n- [ ] tests added / passed\r\n- [ ] Ensure all linting tests pass, see [here](https://pandas.pydata.org/pandas-docs/dev/development/contributing.html#code-standards) for how to run them\r\n- [ ] whatsnew entry\r\n\r\nHandle ignored mypy errors in ``pandas/core/arraylike.py``.',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39103',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39103/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39103/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39103/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/39103',
#   'id': 783355986,
#   'node_id': 'MDU6SXNzdWU3ODMzNTU5ODY=',
#   'number': 39103,
#   'title': "BUG: GroupBy dictionary aggregation raises ValueError when 'as_index=False'",
#   'user': {'login': 'dchigarev',
#    'id': 62142979,
#    'node_id': 'MDQ6VXNlcjYyMTQyOTc5',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/62142979?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dchigarev',
#    'html_url': 'https://github.com/dchigarev',
#    'followers_url': 'https://api.github.com/users/dchigarev/followers',
#    'following_url': 'https://api.github.com/users/dchigarev/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/dchigarev/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/dchigarev/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/dchigarev/subscriptions',
#    'organizations_url': 'https://api.github.com/users/dchigarev/orgs',
#    'repos_url': 'https://api.github.com/users/dchigarev/repos',
#    'events_url': 'https://api.github.com/users/dchigarev/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/dchigarev/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-01-11T13:06:46Z',
#   'updated_at': '2021-01-11T13:09:39Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '- [x] I have checked that this issue has not already been reported.\r\n\r\n- [x] I have confirmed this bug exists on the latest version of pandas.\r\n\r\n- [ ] (optional) I have confirmed this bug exists on the master branch of pandas.\r\n\r\n---\r\n\r\n#### Code Sample, a copy-pastable example\r\n\r\n```python\r\nimport numpy as np\r\nimport pandas\r\n\r\n# Could be any data with MultiIndex columns\r\ndata = {(f"col{i}", f"level-{i % 2}"): np.arange(5) for i in range(5)}\r\ndf = pandas.DataFrame(data)\r\n\r\nby = df.columns[0]\r\nagg_col = df.columns[1]\r\n\r\nagg_dict = {agg_col: ["min", "max"]}\r\ndf.groupby(by, as_index=False).agg(func=agg_dict)  # ValueError\r\n\r\n```\r\n\r\n<details><summary>Traceback</summary>\r\n\r\n```\r\nTraceback (most recent call last):\r\n  File "../exp.py", line 12, in <module>\r\n    df.groupby(by, as_index=False).agg(func=agg_dict)  # ValueError\r\n  File "/localdisk/dchigare/miniconda3/envs/modin_tests/lib/python3.7/site-packages/pandas/core/groupby/generic.py", line 990, in aggregate\r\n    self._insert_inaxis_grouper_inplace(result)\r\n  File "/localdisk/dchigare/miniconda3/envs/modin_tests/lib/python3.7/site-packages/pandas/core/groupby/generic.py", line 1614, in _insert_inaxis_grouper_inplace\r\n    result.insert(0, name, lev)\r\n  File "/localdisk/dchigare/miniconda3/envs/modin_tests/lib/python3.7/site-packages/pandas/core/frame.py", line 3760, in insert\r\n    self._mgr.insert(loc, column, value, allow_duplicates=allow_duplicates)\r\n  File "/localdisk/dchigare/miniconda3/envs/modin_tests/lib/python3.7/site-packages/pandas/core/internals/managers.py", line 1197, in insert\r\n    new_axis = self.items.insert(loc, item)\r\n  File "/localdisk/dchigare/miniconda3/envs/modin_tests/lib/python3.7/site-packages/pandas/core/indexes/multi.py", line 3801, in insert\r\n    item = self._validate_fill_value(item)\r\n  File "/localdisk/dchigare/miniconda3/envs/modin_tests/lib/python3.7/site-packages/pandas/core/indexes/multi.py", line 3784, in _validate_fill_value\r\n    raise ValueError("Item must have length equal to number of levels.")\r\nValueError: Item must have length equal to number of levels.\r\n```\r\n\r\n</details>\r\n\r\n#### Problem description\r\n\r\nWhen we specify an aggregation function via list, pandas adds a new level with function name to the columns of the resulted frame:\r\n```python\r\n>>> df\r\n   col0  col1\r\n0     0     0\r\n>>> df.groupby("col0").agg({"col1": ["max"]})\r\n     col1\r\n      max\r\ncol0\r\n0       0\r\n```\r\nIn the result, the number of levels in the index which represents grouper and columns is different, which causes some problems in [`_insert_inaxis_grouper_inplace`](https://github.com/pandas-dev/pandas/blob/3bd3d1ec253a8a18ac951511820eb970f62baaed/pandas/core/groupby/generic.py#L1610-L1621). When we\'re trying to insert MultiIndex grouper inside the resulted frame, but their `nlevels` is different, `pandas.DataFrame.insert` raises a `ValueError` because of it. \r\n\r\nFilling mismatched levels with an empty string (like pandas already does when inserted value don\'t have MultiIndex columns) will probably solve this issue\r\n```python\r\n>>> df.groupby("col0", as_index=False).agg({"col1": ["max"]}).columns\r\nMultiIndex([(\'col0\',    \'\'),\r\n            (\'col1\', \'max\')],\r\n           )\r\n```\r\n\r\n#### Output of ``pd.show_versions()``\r\n\r\n<details>\r\n\r\n```\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 3e89b4c4b1580aa890023fc550774e63d499da25\r\npython           : 3.7.7.final.0\r\npython-bits      : 64\r\nOS               : Linux\r\nOS-release       : 4.15.0-50-generic\r\nVersion          : #54-Ubuntu SMP Mon May 6 18:46:08 UTC 2019\r\nmachine          : x86_64\r\nprocessor        : x86_64\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : en_US.UTF-8\r\nLOCALE           : en_US.UTF-8\r\n\r\npandas           : 1.2.0\r\nnumpy            : 1.19.0\r\npytz             : 2020.1\r\ndateut ...
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39102',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39102/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39102/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39102/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/39102',
#   'id': 783352257,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NTUyNzI1ODU5',
#   'number': 39102,
#   'title': 'MOVE: describe to pandas/core/describe.py',
#   'user': {'login': 'ivanovmg',
#    'id': 41443370,
#    'node_id': 'MDQ6VXNlcjQxNDQzMzcw',
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/41443370?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ivanovmg',
#    'html_url': 'https://github.com/ivanovmg',
#    'followers_url': 'https://api.github.com/users/ivanovmg/followers',
#    'following_url': 'https://api.github.com/users/ivanovmg/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/ivanovmg/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/ivanovmg/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/ivanovmg/subscriptions',
#    'organizations_url': 'https://api.github.com/users/ivanovmg/orgs',
#    'repos_url': 'https://api.github.com/users/ivanovmg/repos',
#    'events_url': 'https://api.github.com/users/ivanovmg/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/ivanovmg/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 127681,
#     'node_id': 'MDU6TGFiZWwxMjc2ODE=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Refactor',
#     'name': 'Refactor',
#     'color': 'FCE94F',
#     'default': False,
#     'description': 'Internal refactoring of code'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/80',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/80',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/80/labels',
#    'id': 6095818,
#    'node_id': 'MDk6TWlsZXN0b25lNjA5NTgxOA==',
#    'number': 80,
#    'title': '1.3',
#    'description': '',
#    'creator': {'login': 'jreback',
#     'id': 953992,
#     'node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#     'avatar_url': 'https://avatars2.githubusercontent.com/u/953992?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jreback',
#     'html_url': 'https://github.com/jreback',
#     'followers_url': 'https://api.github.com/users/jreback/followers',
#     'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jreback/orgs',
#     'repos_url': 'https://api.github.com/users/jreback/repos',
#     'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jreback/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 77,
#    'closed_issues': 461,
#    'state': 'open',
#    'created_at': '2020-11-11T19:05:43Z',
#    'updated_at': '2021-01-11T14:52:28Z',
#    'due_on': '2021-05-31T07:00:00Z',
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2021-01-11T13:01:20Z',
#   'updated_at': '2021-01-11T14:42:30Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/39102',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/39102',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/39102.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/39102.patch'},
#   'body': '- [ ] closes #xxxx\r\n- [ ] tests added / passed\r\n- [ ] Ensure all linting tests pass, see [here](https://pandas.pydata.org/pandas-docs/dev/development/contributing.html#code-standards) for how to run them\r\n- [ ] whatsnew entry\r\n\r\nMove ``describe`` functionality to a separate module and prepare for the further refactor/simplification (xref #36833).\r\n\r\n - Created new module ``pandas/core/describe.py``\r\n - Delegate the functionality of ``NDFrame.describe`` to function ``describe_ndframe`` in the new module',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39100',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39100/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39100/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39100/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/39100',
#   'id': 783325788,
#   'node_id': 'MDU6SXNzdWU3ODMzMjU3ODg=',
#   'number': 39100,
#   'title': "BUG: merge by multiindex doesn't work correctly",
#   'user': {'login': 'pgagarinov',
#    'id': 4868370,
#    'node_id': 'MDQ6VXNlcjQ4NjgzNzA=',
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/4868370?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/pgagarinov',
#    'html_url': 'https://github.com/pgagarinov',
#    'followers_url': 'https://api.github.com/users/pgagarinov/followers',
#    'following_url': 'https://api.github.com/users/pgagarinov/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/pgagarinov/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/pgagarinov/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/pgagarinov/subscriptions',
#    'organizations_url': 'https://api.github.com/users/pgagarinov/orgs',
#    'repos_url': 'https://api.github.com/users/pgagarinov/repos',
#    'events_url': 'https://api.github.com/users/pgagarinov/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/pgagarinov/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-01-11T12:20:29Z',
#   'updated_at': '2021-01-11T13:49:31Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '- [x] I have checked that this issue has not already been reported.\r\n\r\n- [x] I have confirmed this bug exists on the latest version of pandas.\r\n\r\n- [ ] (optional) I have confirmed this bug exists on the master branch of pandas.\r\n\r\n#### Code Sample, a copy-pastable example\r\n\r\n```python\r\nimport pandas as pd\r\nimport numpy as np\r\n\r\na_dict = {\'val-single-trial-LitPrettyBoringMNIST_f1\': {(0,\r\n   \'Train/Val\',\r\n   (\'train\', \'val\')): 0.1189,\r\n  (1, \'Train/Val\', (\'train\', \'val\')): 0.1373,\r\n  (2, \'Train/Val\', (\'train\', \'val\')): 0.3173,\r\n  (2, \'Reval\', (\'reval\',)): 0.3173,\r\n  (2, \'Test\', (\'test\',)): 0.3173}}\r\n\r\na_df = pd.DataFrame(a_dict)\r\n\r\na_df.index = a_df.index.set_names([\'epoch\', \'stage\', \'stage-list\'])\r\n\r\na_df = a_df.iloc[[0,1,4,2, 3],:]\r\n\r\nb_dict = {\'reval-hyper-opt-LitPrettyBoringMNIST_f1\': {(0, \'Reval\', (\'reval\',)): 0.0317,\r\n  (0, \'Test\', (\'test\',)): np.nan}}\r\n\r\nb_df = pd.DataFrame(b_dict)\r\n\r\nb_df.index = b_df.index.set_names([\'epoch\', \'stage\', \'stage-list\'])\r\n\r\n\r\nbad_merge_df = a_df.merge(b_df, how=\'outer\', left_index=True, right_index=True)\r\n\r\ngood_merge_df = a_df.merge(b_df, how=\'outer\', on=[\'epoch\', \'stage\', \'stage-list\'])\r\n\r\n```\r\nSame example on calab\r\nhttps://colab.research.google.com/drive/1kz2ddulSuC4o3w580wk1iiiU8KJPll1U#scrollTo=2ZCn944CXDRG\r\n\r\n\r\n#### Problem description\r\nbad_merge_df contains a lot of nans:\r\n\r\n<img width="810" alt="image" src="https://user-images.githubusercontent.com/4868370/104181719-5368dd00-5420-11eb-8fdd-6de500c02d25.png">\r\n\r\n#### Expected Output\r\n\r\n<img width="840" alt="image" src="https://user-images.githubusercontent.com/4868370/104181775-68457080-5420-11eb-9c34-45af8797f218.png">\r\n\r\n\r\n#### Output of ``pd.show_versions()``\r\n\r\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 3e89b4c4b1580aa890023fc550774e63d499da25\r\npython           : 3.8.5.final.0\r\npython-bits      : 64\r\nOS               : Linux\r\nOS-release       : 5.4.85-1-MANJARO\r\nVersion          : #1 SMP PREEMPT Mon Dec 21 21:38:53 UTC 2020\r\nmachine          : x86_64\r\nprocessor        : \r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : en.UTF-8\r\nLOCALE           : None.None\r\n\r\npandas           : 1.2.0\r\nnumpy            : 1.19.5\r\npytz             : 2020.5\r\ndateutil         : 2.8.1\r\npip              : 20.3.3\r\nsetuptools       : 49.6.0.post20210108\r\nCython           : None\r\npytest           : 6.2.1\r\nhypothesis       : None\r\nsphinx           : None\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : None\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : 2.11.2\r\nIPython          : 7.19.0\r\npandas_datareader: None\r\nbs4              : None\r\nbottleneck       : None\r\nfsspec           : 0.8.5\r\nfastparquet      : None\r\ngcsfs            : None\r\nmatplotlib       : 3.3.3\r\nnumexpr          : None\r\nodfpy            : None\r\nopenpyxl         : None\r\npandas_gbq       : None\r\npyarrow          : 2.0.0\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : 1.6.0\r\nsqlalchemy       : 1.3.22\r\ntables           : None\r\ntabulate         : 0.8.7\r\nxarray           : None\r\nxlrd             : None\r\nxlwt             : None\r\nnumba            : 0.52.0\r\n\r\n</details>\r\n',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39098',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39098/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39098/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39098/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/39098',
#   'id': 783076118,
#   'node_id': 'MDU6SXNzdWU3ODMwNzYxMTg=',
#   'number': 39098,
#   'title': 'BUG: Groupby agg on decimal,json extension arrays changes dtype to object',
#   'user': {'login': 'BryanCutler',
#    'id': 4534389,
#    'node_id': 'MDQ6VXNlcjQ1MzQzODk=',
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/4534389?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/BryanCutler',
#    'html_url': 'https://github.com/BryanCutler',
#    'followers_url': 'https://api.github.com/users/BryanCutler/followers',
#    'following_url': 'https://api.github.com/users/BryanCutler/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/BryanCutler/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/BryanCutler/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/BryanCutler/subscriptions',
#    'organizations_url': 'https://api.github.com/users/BryanCutler/orgs',
#    'repos_url': 'https://api.github.com/users/BryanCutler/repos',
#    'events_url': 'https://api.github.com/users/BryanCutler/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/BryanCutler/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2021-01-11T05:30:39Z',
#   'updated_at': '2021-01-11T05:31:47Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'body': '- [X] I have checked that this issue has not already been reported.\r\n\r\n- [X] I have confirmed this bug exists on the latest version of pandas.\r\n\r\n- [X] (optional) I have confirmed this bug exists on the master branch of pandas.\r\n\r\n---\r\n\r\n#### Code Sample, a copy-pastable example\r\n\r\n```python\r\nimport decimal\r\nfrom pandas.tests.extension.decimal import DecimalArray\r\nimport pandas as pd\r\n\r\nb = decimal.Decimal("1.0")\r\na = decimal.Decimal("0.0")\r\nc = decimal.Decimal("2.0")\r\nna = decimal.Decimal("NaN")\r\n\r\ndf = pd.DataFrame({\r\n    \'key\': [1, 1, 2, 2, 3, 3, 1, 4], \r\n    \'val\': DecimalArray([b, b, na, na, a, a, b, c])\r\n})\r\n\r\nresult = df.groupby("key").agg({\'val\': \'first\'})\r\n\r\nprint(result[\'val\').dtype)\r\n# object\r\n```\r\n\r\n#### Problem description\r\n\r\nWhen performing a `groupby().agg()` on extension arrays `DecimalArray` or `JsonArray`, if a NULL value is present, the resulting aggregation will be converted to an `object` dtype.\r\n\r\n#### Expected Output\r\n\r\nResulting series should be the same dtype as the input array, and any NULL values should be as defined in the extension dtype.\r\n\r\n\r\n#### Output of ``pd.show_versions()``\r\n\r\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 1c296b20f7ab9822dacaa894afecd960bb43fc47\r\npython           : 3.8.6.final.0\r\npython-bits      : 64\r\nOS               : Linux\r\nOS-release       : 5.4.0-58-generic\r\nVersion          : #64-Ubuntu SMP Wed Dec 9 08:16:25 UTC 2020\r\nmachine          : x86_64\r\nprocessor        : x86_64\r\nbyteorder        : little\r\nLC_ALL           : C.UTF-8\r\nLANG             : C.UTF-8\r\nLOCALE           : en_US.UTF-8\r\n\r\npandas           : 1.3.0.dev0+357.g1c296b20f.dirty\r\nnumpy            : 1.19.4\r\npytz             : 2020.4\r\ndateutil         : 2.8.1\r\npip              : 20.0.2\r\nsetuptools       : 49.6.0.post20201009\r\nCython           : 0.29.21\r\npytest           : 6.1.2\r\nhypothesis       : 5.41.5\r\nsphinx           : 3.3.1\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : 1.3.7\r\nlxml.etree       : 4.6.2\r\nhtml5lib         : 1.1\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : 2.11.2\r\nIPython          : 7.19.0\r\npandas_datareader: None\r\nbs4              : 4.9.3\r\nbottleneck       : 1.3.2\r\nfsspec           : 0.8.4\r\nfastparquet      : 0.4.1\r\ngcsfs            : 0.7.1\r\nmatplotlib       : 3.3.3\r\nnumexpr          : 2.7.1\r\nodfpy            : None\r\nopenpyxl         : 3.0.5\r\npandas_gbq       : None\r\npyarrow          : 2.0.0\r\npyxlsb           : None\r\ns3fs             : 0.4.2\r\nscipy            : 1.5.3\r\nsqlalchemy       : 1.3.20\r\ntables           : 3.6.1\r\ntabulate         : 0.8.7\r\nxarray           : 0.16.2\r\nxlrd             : 1.2.0\r\nxlwt             : 1.3.0\r\nnumba            : 0.52.0\r\n\r\n</details>\r\n',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39097',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39097/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39097/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39097/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/39097',
#   'id': 782938704,
#   'node_id': 'MDU6SXNzdWU3ODI5Mzg3MDQ=',
#   'number': 39097,
#   'title': 'BUG: DateOffset applied to DatetimeIndex losing freq starting in v1.1.0',
#   'user': {'login': 'bexer',
#    'id': 2894002,
#    'node_id': 'MDQ6VXNlcjI4OTQwMDI=',
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/2894002?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/bexer',
#    'html_url': 'https://github.com/bexer',
#    'followers_url': 'https://api.github.com/users/bexer/followers',
#    'following_url': 'https://api.github.com/users/bexer/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/bexer/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/bexer/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/bexer/subscriptions',
#    'organizations_url': 'https://api.github.com/users/bexer/orgs',
#    'repos_url': 'https://api.github.com/users/bexer/repos',
#    'events_url': 'https://api.github.com/users/bexer/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/bexer/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-01-11T00:01:58Z',
#   'updated_at': '2021-01-11T00:01:58Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '- [x] I have checked that this issue has not already been reported.\r\n\r\n- [x] I have confirmed this bug exists on the latest version of pandas.\r\n\r\n- [ ] (optional) I have confirmed this bug exists on the master branch of pandas.\r\n\r\n---\r\n\r\n#### Code Sample, a copy-pastable example\r\n\r\n```python\r\nimport pandas as pd\r\n\r\ndtsa = pd.date_range(\'1998\', periods = 3, freq = \'A\')\r\ns1 = pd.Series([4,5,6], index=dtsa)\r\ns1.index\r\n# DatetimeIndex([\'1998-12-31\', \'1999-12-31\', \'2000-12-31\'], dtype=\'datetime64[ns]\', freq=\'A-DEC\')\r\n\r\ni1 = s1.index + pd.DateOffset(years=-1, days=1)\r\ni1\r\n# DatetimeIndex([\'1998-01-01\', \'1999-01-01\', \'2000-01-01\'], dtype=\'datetime64[ns]\', freq=None)\r\n```\r\n\r\n#### Problem description\r\n\r\nI expected **i1** to have the frequency "AS-JAN" instead of None. This behavior existed prior to version 1.1.0. For example, in 1.0.5 the output of the same commands is:\r\n```python\r\n> DatetimeIndex([\'1998-01-01\', \'1999-01-01\', \'2000-01-01\'], dtype=\'datetime64[ns]\', freq=\'AS-JAN\')\r\n```\r\n\r\n#### Expected Output\r\n\r\n```python\r\n> DatetimeIndex([\'1998-01-01\', \'1999-01-01\', \'2000-01-01\'], dtype=\'datetime64[ns]\', freq=\'AS-JAN\')\r\n```\r\n\r\n#### Output of ``pd.show_versions()``\r\n\r\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : d9fff2792bf16178d4e450fe7384244e50635733\r\npython           : 3.8.0.final.0\r\npython-bits      : 64\r\nOS               : Windows\r\nOS-release       : 10\r\nVersion          : 10.0.17134\r\nmachine          : AMD64\r\nprocessor        : Intel64 Family 6 Model 94 Stepping 3, GenuineIntel\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : None\r\nLOCALE           : English_United States.1252\r\n\r\npandas           : 1.1.0\r\nnumpy            : 1.19.2\r\npytz             : 2020.5\r\ndateutil         : 2.8.1\r\npip              : 20.3.3\r\nsetuptools       : 51.0.0.post20201207\r\nCython           : None\r\npytest           : None\r\nhypothesis       : None\r\nsphinx           : None\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : None\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : 2.11.2\r\nIPython          : 7.19.0\r\npandas_datareader: None\r\nbs4              : None\r\nbottleneck       : None\r\nfsspec           : None\r\nfastparquet      : None\r\ngcsfs            : None\r\nmatplotlib       : None\r\nnumexpr          : None\r\nodfpy            : None\r\nopenpyxl         : None\r\npandas_gbq       : None\r\npyarrow          : None\r\npytables         : None\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : None\r\nsqlalchemy       : None\r\ntables           : None\r\ntabulate         : None\r\nxarray           : None\r\nxlrd             : None\r\nxlwt             : None\r\nnumba            : None\r\n\r\n</details>\r\n',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39096',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39096/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39096/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39096/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/39096',
#   'id': 782922944,
#   'node_id': 'MDU6SXNzdWU3ODI5MjI5NDQ=',
#   'number': 39096,
#   'title': 'TST/COMPAT: test memory usage failed on macOS after change pytest-xdist -dist to `no`',
#   'user': {'login': 'fangchenli',
#    'id': 7614606,
#    'node_id': 'MDQ6VXNlcjc2MTQ2MDY=',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/7614606?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/fangchenli',
#    'html_url': 'https://github.com/fangchenli',
#    'followers_url': 'https://api.github.com/users/fangchenli/followers',
#    'following_url': 'https://api.github.com/users/fangchenli/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/fangchenli/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/fangchenli/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/fangchenli/subscriptions',
#    'organizations_url': 'https://api.github.com/users/fangchenli/orgs',
#    'repos_url': 'https://api.github.com/users/fangchenli/repos',
#    'events_url': 'https://api.github.com/users/fangchenli/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/fangchenli/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76865106,
#     'node_id': 'MDU6TGFiZWw3Njg2NTEwNg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Compat',
#     'name': 'Compat',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Related to pandas compatibility with other libraries'},
#    {'id': 127685,
#     'node_id': 'MDU6TGFiZWwxMjc2ODU=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Testing',
#     'name': 'Testing',
#     'color': 'C4A000',
#     'default': False,
#     'description': 'Custom testing functions or related to the test suite'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-01-10T22:28:36Z',
#   'updated_at': '2021-01-10T22:29:17Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'body': 'In #38905, I changed the distribution algorithm of pytest-xdist to `no` from `loadfile`.  And the test `pandas/tests/base/test_misc.py:test_memory_usage` failed on macOS.\r\n\r\n```bash\r\nindex_or_series_obj = Series([], Name: a, dtype: float64)\r\n\r\n    @pytest.mark.skipif(PYPY, reason="not relevant for PyPy")\r\n    def test_memory_usage(index_or_series_obj):\r\n        obj = index_or_series_obj\r\n    \r\n        res = obj.memory_usage()\r\n        res_deep = obj.memory_usage(deep=True)\r\n    \r\n        is_object = is_object_dtype(obj) or (\r\n            isinstance(obj, Series) and is_object_dtype(obj.index)\r\n        )\r\n        is_categorical = is_categorical_dtype(obj.dtype) or (\r\n            isinstance(obj, Series) and is_categorical_dtype(obj.index.dtype)\r\n        )\r\n    \r\n        if len(obj) == 0:\r\n            if isinstance(obj, Index):\r\n                expected = 0\r\n            else:\r\n                expected = 108 if IS64 else 64\r\n>           assert res_deep == res == expected\r\nE           assert 0 == 108\r\n```\r\n',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39094',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39094/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39094/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39094/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/39094',
#   'id': 782900078,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NTUyMzQyNzUy',
#   'number': 39094,
#   'title': 'REF: implement dtypes.cast.can_hold_element',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
# ...
#     'site_admin': False},
#    'open_issues': 77,
#    'closed_issues': 461,
#    'state': 'open',
#    'created_at': '2020-11-11T19:05:43Z',
#    'updated_at': '2021-01-11T14:52:28Z',
#    'due_on': '2021-05-31T07:00:00Z',
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2021-01-09T14:25:09Z',
#   'updated_at': '2021-01-10T11:09:39Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/39059',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/39059',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/39059.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/39059.patch'},
#   'body': 'xref #37715',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39053',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39053/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39053/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39053/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/39053',
#   'id': 782594598,
#   'node_id': 'MDU6SXNzdWU3ODI1OTQ1OTg=',
#   'number': 39053,
#   'title': 'ENH: Please provide "universal2" wheels for macOS',
#   'user': {'login': 'ronaldoussoren',
#    'id': 713966,
#    'node_id': 'MDQ6VXNlcjcxMzk2Ng==',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/713966?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ronaldoussoren',
#    'html_url': 'https://github.com/ronaldoussoren',
#    'followers_url': 'https://api.github.com/users/ronaldoussoren/followers',
#    'following_url': 'https://api.github.com/users/ronaldoussoren/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/ronaldoussoren/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/ronaldoussoren/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/ronaldoussoren/subscriptions',
#    'organizations_url': 'https://api.github.com/users/ronaldoussoren/orgs',
#    'repos_url': 'https://api.github.com/users/ronaldoussoren/repos',
#    'events_url': 'https://api.github.com/users/ronaldoussoren/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/ronaldoussoren/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76812,
#     'node_id': 'MDU6TGFiZWw3NjgxMg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Enhancement',
#     'name': 'Enhancement',
#     'color': '4E9A06',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 3,
#   'created_at': '2021-01-09T12:08:52Z',
#   'updated_at': '2021-01-11T07:55:12Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '#### Is your feature request related to a problem?\r\n\r\nThere is a, currently formally experimental, "universal2" installer for Python on www.python.org. This natively supports both x86_64 (macOS 10.9 or later) and arm64 (macOS 11.0 or later).   Using pandas with this installer currently requires building pandas from source, not from a binary wheel.\r\n\r\n#### Describe the solution you\'d like\r\n\r\nA binary wheel on PyPI for the "universal2" installer, next to the "x86_64" wheel there already is.\r\n\r\nIn the longer run I\'d love to see only "universal2" wheels and no "x86_64" wheels, but that at the very least requires time for   support in the packaging system to further mature (support for "universal2" in pip and wheel is pretty new at this point).\r\n',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39051',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39051/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39051/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39051/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/39051',
#   'id': 782561585,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NTUyMDk3Mzky',
#   'number': 39051,
#   'title': 'ENH: try to preserve the dtype on combine_first for the case where the two DataFrame objects have the same columns',
#   'user': {'login': 'danielhrisca',
#    'id': 20952040,
#    'node_id': 'MDQ6VXNlcjIwOTUyMDQw',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/20952040?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/danielhrisca',
#    'html_url': 'https://github.com/danielhrisca',
#    'followers_url': 'https://api.github.com/users/danielhrisca/followers',
#    'following_url': 'https://api.github.com/users/danielhrisca/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/danielhrisca/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/danielhrisca/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/danielhrisca/subscriptions',
#    'organizations_url': 'https://api.github.com/users/danielhrisca/orgs',
#    'repos_url': 'https://api.github.com/users/danielhrisca/repos',
#    'events_url': 'https://api.github.com/users/danielhrisca/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/danielhrisca/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 31404521,
#     'node_id': 'MDU6TGFiZWwzMTQwNDUyMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Dtypes',
#     'name': 'Dtypes',
#     'color': 'e102d8',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2021-01-09T08:27:59Z',
#   'updated_at': '2021-01-11T15:22:11Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/39051',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/39051',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/39051.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/39051.patch'},
#   'body': '…e two DataFrame objects have the same columns\r\n\r\n- [ ] closes #7509 \r\n- [ ] tests added / passed\r\n- [ ] Ensure all linting tests pass, see [here](https://pandas.pydata.org/pandas-docs/dev/development/contributing.html#code-standards) for how to run them\r\n- [ ] whatsnew entry\r\n',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39047',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39047/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39047/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39047/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/39047',
#   'id': 782494701,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NTUyMDQwOTk5',
#   'number': 39047,
#   'title': 'TST: extend check for leaked files',
#   'user': {'login': 'twoertwein',
#    'id': 6618166,
#    'node_id': 'MDQ6VXNlcjY2MTgxNjY=',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/6618166?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/twoertwein',
#    'html_url': 'https://github.com/twoertwein',
#    'followers_url': 'https://api.github.com/users/twoertwein/followers',
#    'following_url': 'https://api.github.com/users/twoertwein/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/twoertwein/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/twoertwein/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/twoertwein/subscriptions',
#    'organizations_url': 'https://api.github.com/users/twoertwein/orgs',
#    'repos_url': 'https://api.github.com/users/twoertwein/repos',
#    'events_url': 'https://api.github.com/users/twoertwein/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/twoertwein/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 127685,
#     'node_id': 'MDU6TGFiZWwxMjc2ODU=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Testing',
#     'name': 'Testing',
#     'color': 'C4A000',
#     'default': False,
#     'description': 'Custom testing functions or related to the test suite'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2021-01-09T02:31:51Z',
#   'updated_at': '2021-01-11T01:02:17Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/39047',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/39047',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/39047.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/39047.patch'},
#   'body': "Use `ResourceWarning`s as indicators of leaked files. I left the `psutil`-based check for leaked files.\r\n\r\nI enabled the check for leaked files for all io tests.\r\n\r\nExisting warnings:\r\n- [ ]  all excel functions using pyxlsb: fixed by https://github.com/willtrnr/pyxlsb/pull/32 and this PR\r\n- [ ]  TestS3.test_write_s3_csv_fails: unclosed `ssl.SSLSocket`\r\n- [ ]  test_skip_row_with_newline_and_quote: multiple unclosed `ssl.SSLSocket` and `socket.socket`\r\n- [ ]  TestSQLApiConn.test_*: unclosed `asyncio.sslproto._SSLProtocolTransport`\r\n- [ ]  TestStata.test_* on windwos:  `ResourceWarning('This save was not successful but C:\\\\Users\\\\VSSADM~1\\\\AppData\\\\Local\\\\Temp\\\\tmpbhavxy1v could not be deleted.  This file is not valid.')`\r\n- [ ] test_server_and_default_headers on windows: unclosed `asyncio.sslproto._SSLProtocolTransport`",
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39044',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39044/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39044/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39044/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/39044',
#   'id': 782435460,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NTUxOTkyNzgy',
#   'number': 39044,
#   'title': 'BUG/API: make setitem-inplace preserve dtype when possible with PandasArray, IntegerArray, FloatingArray',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-01-08T22:30:49Z',
#   'updated_at': '2021-01-09T23:28:27Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/39044',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/39044',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/39044.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/39044.patch'},
#   'body': '- [ ] closes #xxxx\r\n- [x] tests added / passed\r\n- [x] Ensure all linting tests pass, see [here](https://pandas.pydata.org/pandas-docs/dev/development/contributing.html#code-standards) for how to run them\r\n- [ ] whatsnew entry\r\n\r\nxref #38896 (doesn\'t close).  In general `df[:, "A"] = foo` tries to operate in-place before falling back to casting.  This makes sure we do that when `foo` is a `PandasArray`, `IntegerArray`, or `FloatingArray`\r\n\r\nI guess could/should do the same for BooleanArray\r\n',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39043',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39043/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39043/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39043/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/39043',
#   'id': 782430023,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NTUxOTg4NTA2',
#   'number': 39043,
#   'title': 'CI: use conda incubator in doc and benchmarks',
#   'user': {'login': 'fangchenli',
#    'id': 7614606,
#    'node_id': 'MDQ6VXNlcjc2MTQ2MDY=',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/7614606?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/fangchenli',
#    'html_url': 'https://github.com/fangchenli',
#    'followers_url': 'https://api.github.com/users/fangchenli/followers',
#    'following_url': 'https://api.github.com/users/fangchenli/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/fangchenli/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/fangchenli/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/fangchenli/subscriptions',
#    'organizations_url': 'https://api.github.com/users/fangchenli/orgs',
#    'repos_url': 'https://api.github.com/users/fangchenli/repos',
#    'events_url': 'https://api.github.com/users/fangchenli/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/fangchenli/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 48070600,
#     'node_id': 'MDU6TGFiZWw0ODA3MDYwMA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/CI',
#     'name': 'CI',
#     'color': 'a2bca7',
#     'default': False,
#     'description': 'Related to Continuous Integration'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-01-08T22:17:36Z',
#   'updated_at': '2021-01-11T02:28:32Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/39043',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/39043',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/39043.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/39043.patch'},
#   'body': 'The benchmark ci currently has the longest runtime. Using conda incubator would save about 6-8 min.\r\n',
#   'performed_via_github_app': None}]

# %%
import pandas as pd

# %%
issues=pd.DataFrame(data,columns=['number','title','labels','state'])
issues
# Out:
#     number                                              title  \
# 0    39109            DOC: NDFrame fillna method add use case
# 1    39108            TYP: clean notations in the wrong place
# 2    39107  TYP: replace Label alias from pandas._typing w...
# 3    39104   TYP: fix mypy errors in pandas/core/arraylike.py
# 4    39103  BUG: GroupBy dictionary aggregation raises Val...
# 5    39102          MOVE: describe to pandas/core/describe.py
# 6    39100    BUG: merge by multiindex doesn't work correctly
# 7    39098  BUG: Groupby agg on decimal,json extension arr...
# 8    39097  BUG: DateOffset applied to DatetimeIndex losin...
# 9    39096  TST/COMPAT: test memory usage failed on macOS ...
# 10   39094        REF: implement dtypes.cast.can_hold_element
# 11   39093               TYP: NDFrame.pipe, GroupBy.pipe etc.
# 12   39091         DOC: Added reverse rolling window examples
# 13   39089                  CI: Numpy changed dtype inference
# 14   39087                                               BUG:
# 15   39086       BUG: setting td64 value into Series[numeric]
# 16   39079  BUG: read_csv with custom date parser and na_f...
# 17   39072  TST GH26807 Break up pandas/tests/io/pytables/...
# 18   39068  BUG/API: DTI/TDI/PI.insert cast to object on f...
# 19   39067  TYP: prep _generate_range_overflow_safe for nu...
# 20   39064      Added docs for the change of behavior of isin
# 21   39063                     ENH: rolling for periodic data
# 22   39062           TST: skips in extension.test_categorical
# 23   39060                          BUG: in network decorator
# 24   39059                TYP: remove ignore in optional_args
# 25   39053  ENH: Please provide "universal2" wheels for macOS
# 26   39051  ENH: try to preserve the dtype on combine_firs...
# 27   39047                 TST: extend check for leaked files
# 28   39044  BUG/API: make setitem-inplace preserve dtype w...
# 29   39043      CI: use conda incubator in doc and benchmarks
#
#                                                labels state
# 0                                                  []  open
# 1   [{'id': 1280988427, 'node_id': 'MDU6TGFiZWwxMj...  open
# 2   [{'id': 1280988427, 'node_id': 'MDU6TGFiZWwxMj...  open
# 3   [{'id': 1280988427, 'node_id': 'MDU6TGFiZWwxMj...  open
# 4   [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 5   [{'id': 127681, 'node_id': 'MDU6TGFiZWwxMjc2OD...  open
# 6   [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 7   [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 8   [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 9   [{'id': 76865106, 'node_id': 'MDU6TGFiZWw3Njg2...  open
# 10  [{'id': 31404521, 'node_id': 'MDU6TGFiZWwzMTQw...  open
# 11  [{'id': 1280988427, 'node_id': 'MDU6TGFiZWwxMj...  open
# 12  [{'id': 134699, 'node_id': 'MDU6TGFiZWwxMzQ2OT...  open
# 13  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 14  [{'id': 307649777, 'node_id': 'MDU6TGFiZWwzMDc...  open
# 15  [{'id': 2822098, 'node_id': 'MDU6TGFiZWwyODIyM...  open
# 16  [{'id': 47229171, 'node_id': 'MDU6TGFiZWw0NzIy...  open
# 17  [{'id': 47229190, 'node_id': 'MDU6TGFiZWw0NzIy...  open
# 18  [{'id': 211840, 'node_id': 'MDU6TGFiZWwyMTE4ND...  open
# 19  [{'id': 1280988427, 'node_id': 'MDU6TGFiZWwxMj...  open
# 20  [{'id': 134699, 'node_id': 'MDU6TGFiZWwxMzQ2OT...  open
# 21  [{'id': 76812, 'node_id': 'MDU6TGFiZWw3NjgxMg=...  open
# 22  [{'id': 78527356, 'node_id': 'MDU6TGFiZWw3ODUy...  open
# 23  [{'id': 127685, 'node_id': 'MDU6TGFiZWwxMjc2OD...  open
# 24  [{'id': 1280988427, 'node_id': 'MDU6TGFiZWwxMj...  open
# 25  [{'id': 76812, 'node_id': 'MDU6TGFiZWw3NjgxMg=...  open
# 26  [{'id': 31404521, 'node_id': 'MDU6TGFiZWwzMTQw...  open
# 27  [{'id': 127685, 'node_id': 'MDU6TGFiZWwxMjc2OD...  open
# 28                                                 []  open
# 29  [{'id': 48070600, 'node_id': 'MDU6TGFiZWw0ODA3...  open

# %% [markdown]
# # Interacting with DATABASES

# %%
import sqlite3

# %%
con=sqlite3.connect('mydata2.sqlite')

# %%
db

# %%
con.execute('drop table if exists test')

# %%
con

# %%
query="""
CREATE TABLE test
(a VARCHAR(20), b VARCHAR(20),
c REAL, d INTEGER
);
"""

con.execute(query)
con.commit()

# %%
con=sqlite3.connect('mydata2.sqlite')
data = [('Atlanta', 'Georgia', 1.25, 6),
        ('Tallahassee', 'Florida', 2.6, 3),
        ('Sacramento', 'California', 1.7, 5)]
stmt = "INSERT INTO test VALUES(?, ?, ?, ?)"
con.executemany(stmt, data)
con.commit()

# %%
cursor=con.execute('select * from test')
rows=cursor.fetchall()
rows
# Out:
# [('Atlanta', 'Georgia', 1.25, 6),
#  ('Tallahassee', 'Florida', 2.6, 3),
#  ('Sacramento', 'California', 1.7, 5),
#  ('Atlanta', 'Georgia', 1.25, 6),
#  ('Tallahassee', 'Florida', 2.6, 3),
#  ('Sacramento', 'California', 1.7, 5)]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
titanic_train = pd.read_csv("https://gist.githubusercontent.com/michhar/2dfd2de0d4f8727f873422c5d959fff5/raw/ff414a1bcfcba32481e4d4e8db578e55872a2ca1/titanic.csv",
                           sep='\t')

# %%
titanic_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 151                  Pears, Mrs. Thomas (Edith Wearne)  female  22.0      1
# 152                                   Meo, Mr. Alfonzo    male  55.5      0
# 153                    van Billiard, Mr. Austin Blyler    male  40.5      0
# 154                              Olsen, Mr. Ole Martin    male   NaN      0
# 155                        Williams, Mr. Charles Duane    male  51.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 151      0            113776  66.6000    C2        S
# 152      0        A.5. 11206   8.0500   NaN        S
# 153      2          A/5. 851  14.5000   NaN        S
# 154      0         Fa 265302   7.3125   NaN        S
# 155      1          PC 17597  61.3792   NaN        C
#
# [156 rows x 12 columns]

# %%
titanic_train.tail()
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 151          152         1       1  Pears, Mrs. Thomas (Edith Wearne)  female
# 152          153         0       3                   Meo, Mr. Alfonzo    male
# 153          154         0       3    van Billiard, Mr. Austin Blyler    male
# 154          155         0       3              Olsen, Mr. Ole Martin    male
# 155          156         0       1        Williams, Mr. Charles Duane    male
#
#       Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 151  22.0      1      0      113776  66.6000    C2        S
# 152  55.5      0      0  A.5. 11206   8.0500   NaN        S
# 153  40.5      0      2    A/5. 851  14.5000   NaN        S
# 154   NaN      0      0   Fa 265302   7.3125   NaN        S
# 155  51.0      0      1    PC 17597  61.3792   NaN        C

# %%
titanic_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  156 non-null    int64
#  1   Survived     156 non-null    int64
#  2   Pclass       156 non-null    int64
#  3   Name         156 non-null    object
#  4   Sex          156 non-null    object
#  5   Age          126 non-null    float64
#  6   SibSp        156 non-null    int64
#  7   Parch        156 non-null    int64
#  8   Ticket       156 non-null    object
#  9   Fare         156 non-null    float64
#  10  Cabin        31 non-null     object
#  11  Embarked     155 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 14.8+ KB

# %%
titanic_train.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
titanic_train.dtypes=='object'
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
titanic_train.loc[titanic_train[titanic_train.dtypes=='object']]
# Out:
# C:\Users\SNARAHA1\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-52-da2e717aa367> in <module>
# ----> 1 titanic_train.loc[titanic_train[titanic_train.dtypes=='object']]
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2789         # Do we have a (boolean) 1d indexer?
#    2790         if com.is_bool_indexer(key):
# -> 2791             return self._getitem_bool_array(key)
#    2792
#    2793         # We are left with two options: a single key, and a collection of keys,
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_bool_array(self, key)
#    2841         # check_bool_indexer will throw exception if Series key cannot
#    2842         # be reindexed to match DataFrame rows
# -> 2843         key = check_bool_indexer(self.index, key)
#    2844         indexer = key.nonzero()[0]
#    2845         return self._take_with_is_copy(indexer, axis=0)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py in check_bool_indexer(index, key)
#    2316         if mask.any():
#    2317             raise IndexingError(
# -> 2318                 "Unalignable boolean Series provided as "
#    2319                 "indexer (index of the boolean Series and of "
#    2320                 "the indexed object do not match)."
#
# IndexingError: Unalignable boolean Series provided as indexer (index of the boolean Series and of the indexed object do not match).

# %%
titanic_train.dtypes[titanic_train.dtypes=='object'].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
a=titanic_train[titanic_train.dtypes[titanic_train.dtypes=='object'].index]
a
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 151                  Pears, Mrs. Thomas (Edith Wearne)  female
# 152                                   Meo, Mr. Alfonzo    male
# 153                    van Billiard, Mr. Austin Blyler    male
# 154                              Olsen, Mr. Ole Martin    male
# 155                        Williams, Mr. Charles Duane    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# 4              373450   NaN        S
# ..                ...   ...      ...
# 151            113776    C2        S
# 152        A.5. 11206   NaN        S
# 153          A/5. 851   NaN        S
# 154         Fa 265302   NaN        S
# 155          PC 17597   NaN        C
#
# [156 rows x 5 columns]

# %%
a.describe()
# Out:
#                                 Name   Sex  Ticket Cabin Embarked
# count                            156   156     156    31      155
# unique                           156     2     145    28        3
# top     Williams, Mr. Charles Eugene  male  347082  C123        S
# freq                               1   100       2     2      110

# %%
titanic_train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   156.000000  156.000000  156.000000  126.000000  156.000000
# mean     78.500000    0.346154    2.423077   28.141508    0.615385
# std      45.177428    0.477275    0.795459   14.613880    1.056235
# min       1.000000    0.000000    1.000000    0.830000    0.000000
# 25%      39.750000    0.000000    2.000000   19.000000    0.000000
# 50%      78.500000    0.000000    3.000000   26.000000    0.000000
# 75%     117.250000    1.000000    3.000000   35.000000    1.000000
# max     156.000000    1.000000    3.000000   71.000000    5.000000
#
#             Parch        Fare
# count  156.000000  156.000000
# mean     0.397436   28.109587
# std      0.870146   39.401047
# min      0.000000    6.750000
# 25%      0.000000    8.003150
# 50%      0.000000   14.454200
# 75%      0.000000   30.371850
# max      5.000000  263.000000

# %%
titanic_train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             30
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          125
# Embarked         1
# dtype: int64

# %%
titanic_train.value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-63-803a3c177564> in <module>
# ----> 1 titanic_train.value_counts()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'value_counts'

# %%
titanic_train.isnull().value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-64-cf16225c74f4> in <module>
# ----> 1 titanic_train.isnull().value_counts()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'value_counts'

# %%
sorted(titanic_train['Name'])
# Out:
# ['Ahlin, Mrs. Johan (Johanna Persdotter Larsson)',
#  'Allen, Mr. William Henry',
#  'Andersson, Miss. Ellis Anna Maria',
#  'Andersson, Miss. Erna Alexandra',
#  'Andersson, Mr. Anders Johan',
#  'Andersson, Mr. August Edvard ("Wennerstrom")',
#  'Andreasson, Mr. Paul Edvin',
#  'Andrew, Mr. Edgardo Samuel',
#  'Arnold-Franchi, Mrs. Josef (Josefine Franchi)',
#  'Asplund, Mrs. Carl Oscar (Selma Augusta Emilia Johansson)',
#  'Attalah, Miss. Malake',
#  'Backstrom, Mrs. Karl Alfred (Maria Mathilda Gustafsson)',
#  'Barton, Mr. David John',
#  'Bateman, Rev. Robert James',
#  'Baxter, Mr. Quigg Edmond',
#  'Beesley, Mr. Lawrence',
#  'Bing, Mr. Lee',
#  'Bonnell, Miss. Elizabeth',
#  'Boulos, Mrs. Joseph (Sultana)',
#  'Braund, Mr. Owen Harris',
#  'Burke, Mr. Jeremiah',
#  'Byles, Rev. Thomas Roussel Davids',
#  'Caldwell, Master. Alden Gates',
#  'Cann, Mr. Ernest Charles',
#  'Carrau, Mr. Francisco M',
#  'Celotti, Mr. Francesco',
#  'Chaffee, Mr. Herbert Fuller',
#  'Christmann, Mr. Emil',
#  'Chronopoulos, Mr. Apostolos',
#  'Coelho, Mr. Domingos Fernandeo',
#  'Connors, Mr. Patrick',
#  'Coxon, Mr. Daniel',
#  'Crease, Mr. Ernest James',
#  'Cumings, Mrs. John Bradley (Florence Briggs Thayer)',
#  'Dean, Mr. Bertram Frank',
#  'Devaney, Miss. Margaret Delia',
#  'Doling, Mrs. John T (Ada Julia Bone)',
#  'Dowdell, Miss. Elizabeth',
#  'Drazenoic, Mr. Jozef',
#  'Ekstrom, Mr. Johan',
#  'Emir, Mr. Farred Chehab',
#  'Faunthorpe, Mrs. Lizzie (Elizabeth Anne Wilkinson)',
#  'Ford, Miss. Robina Maggie "Ruby"',
#  'Ford, Mr. William Neal',
#  'Fortune, Miss. Mabel Helen',
#  'Fortune, Mr. Charles Alexander',
#  'Futrelle, Mr. Jacques Heath',
#  'Futrelle, Mrs. Jacques Heath (Lily May Peel)',
#  'Fynney, Mr. Joseph J',
#  'Giglio, Mr. Victor',
#  'Glynn, Miss. Mary Agatha',
#  'Goldschmidt, Mr. George B',
#  'Goodwin, Master. William Frederick',
#  'Goodwin, Miss. Lillian Amy',
#  'Greenfield, Mr. William Bertram',
#  'Gustafsson, Mr. Anders Vilhelm',
#  'Hakkarainen, Mrs. Pekka Pietari (Elin Matilda Dolck)',
#  'Harper, Mrs. Henry Sleeper (Myna Haxtun)',
#  'Harris, Mr. Henry Birkhardt',
#  'Heikkinen, Miss. Laina',
#  'Hewlett, Mrs. (Mary D Kingcome) ',
#  'Hickman, Mr. Stanley George',
#  'Holverson, Mr. Alexander Oskar',
#  'Hood, Mr. Ambrose Jr',
#  'Icard, Miss. Amelie',
#  'Ilett, Miss. Bertha',
#  'Jenkin, Mr. Stephen Curnow',
#  'Johansson, Mr. Gustaf Joel',
#  'Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)',
#  'Jussila, Miss. Katriina',
#  'Kantor, Mr. Sinai',
#  'Kink, Mr. Vincenz',
#  'Kraeff, Mr. Theodor',
#  'Laroche, Miss. Simonne Marie Anne Andree',
#  'Lennon, Mr. Denis',
#  'Madsen, Mr. Fridtjof Arne',
#  'Mamee, Mr. Hanna',
#  'Masselmani, Mrs. Fatima',
#  'McCarthy, Mr. Timothy J',
#  'McDermott, Miss. Brigdet Delia',
#  'McGowan, Miss. Anna "Annie"',
#  'McMahon, Mr. Martin',
#  'Meo, Mr. Alfonzo',
#  'Meyer, Mr. Edgar Joseph',
#  'Mionoff, Mr. Stoytcho',
#  'Moen, Mr. Sigurd Hansen',
#  'Moore, Mr. Leonard Charles',
#  'Moran, Miss. Bertha',
#  'Moran, Mr. James',
#  'Moss, Mr. Albert Johan',
#  'Moubarek, Master. Gerios',
#  'Moutal, Mr. Rahamin Haim',
#  'Nasser, Mr. Nicholas',
#  'Nasser, Mrs. Nicholas (Adele Achem)',
#  'Navratil, Mr. Michel ("Louis M Hoffman")',
#  'Newsom, Miss. Helen Monypeny',
#  'Nicholls, Mr. Joseph Charles',
#  'Nicola-Yarred, Master. Elias',
#  'Nicola-Yarred, Miss. Jamila',
#  'Nosworthy, Mr. Richard Cater',
#  'Novel, Mr. Mansouer',
#  'Nye, Mrs. (Elizabeth Ramell)',
#  'Nysten, Miss. Anna Sofia',
#  "O'Driscoll, Miss. Bridget",
#  'O\'Dwyer, Miss. Ellen "Nellie"',
#  'Olsen, Mr. Ole Martin',
#  'Osen, Mr. Olaf Elon',
#  'Ostby, Mr. Engelhart Cornelius',
#  'Palsson, Master. Gosta Leonard',
#  'Palsson, Miss. Torborg Danira',
#  'Panula, Master. Juha Niilo',
#  'Pears, Mrs. Thomas (Edith Wearne)',
#  'Pekoniemi, Mr. Edvard',
#  'Peter, Miss. Anna',
#  'Petranec, Miss. Matilda',
#  'Petroff, Mr. Pastcho ("Pentcho")',
#  'Porter, Mr. Walter Chamberlain',
#  'Rekic, Mr. Tido',
#  'Rice, Master. Eugene',
#  'Richard, Mr. Emile',
#  'Robins, Mrs. Alexander A (Grace Charity Laury)',
#  'Rogers, Mr. William John',
#  'Rugg, Miss. Emily',
#  'Salkjelsvik, Miss. Anna Kristine',
#  'Samaan, Mr. Youssef',
#  'Sandstrom, Miss. Marguerite Rut',
#  'Saundercock, Mr. William Henry',
#  'Sheerlinck, Mr. Jan Baptist',
#  'Shorney, Mr. Charles Joseph',
#  'Sirayanian, Mr. Orsen',
#  'Skoog, Master. Harald',
#  'Slocovski, Mr. Selman Francis',
#  'Sloper, Mr. William Thompson',
#  'Sobey, Mr. Samuel James Hayden',
#  'Spencer, Mrs. William Augustus (Marie Eugenie)',
#  'Staneff, Mr. Ivan',
#  'Stewart, Mr. Albert A',
#  'Todoroff, Mr. Lalio',
#  'Turpin, Mr. William John Robert',
#  'Turpin, Mrs. William John Robert (Dorothy Ann Wonnacott)',
#  'Uruchurtu, Don. Manuel E',
#  'Vander Planke, Miss. Augusta Maria',
#  'Vander Planke, Mrs. Julius (Emelia Maria Vandemoortele)',
#  'Vestrom, Miss. Hulda Amanda Adolfina',
#  'Waelens, Mr. Achille',
#  'Webber, Miss. Susan',
#  'Weisz, Mrs. Leopold (Mathilde Francoise Pede)',
#  'West, Miss. Constance Mirium',
#  'Wheadon, Mr. Edward H',
#  'White, Mr. Percival Wayland',
#  'White, Mr. Richard Frasar',
#  'Williams, Mr. Charles Duane',
#  'Williams, Mr. Charles Eugene',
#  'Woolner, Mr. Hugh',
#  'Zabour, Miss. Hileni',
#  'van Billiard, Mr. Austin Blyler']

# %%
sorted(titanic_train['Name'])[5:10:2]
# Out:
# ['Andersson, Mr. August Edvard ("Wennerstrom")',
#  'Andrew, Mr. Edgardo Samuel',
#  'Asplund, Mrs. Carl Oscar (Selma Augusta Emilia Johansson)']

# %%
titanic_train['Name'].value_counts()
# Out:
# Williams, Mr. Charles Eugene      1
# Nysten, Miss. Anna Sofia          1
# Saundercock, Mr. William Henry    1
# White, Mr. Percival Wayland       1
# Attalah, Miss. Malake             1
#                                  ..
# Rugg, Miss. Emily                 1
# Crease, Mr. Ernest James          1
# Nye, Mrs. (Elizabeth Ramell)      1
# Todoroff, Mr. Lalio               1
# Sheerlinck, Mr. Jan Baptist       1
# Name: Name, Length: 156, dtype: int64

# %%
titanic_train['Age'].value_counts()
# Out:
# 21.00    8
# 29.00    6
# 19.00    6
# 22.00    6
# 24.00    5
# 28.00    5
# 38.00    4
# 26.00    4
# 20.00    4
# 16.00    3
# 34.00    3
# 14.00    3
# 33.00    3
# 23.00    3
# 2.00     3
# 27.00    3
# 18.00    3
# 35.00    3
# 17.00    3
# 45.00    2
# 51.00    2
# 42.00    2
# 4.00     2
# 40.00    2
# 32.00    2
# 25.00    2
# 54.00    2
# 37.00    2
# 47.00    2
# 32.50    2
# 58.00    1
# 8.00     1
# 39.00    1
# 55.00    1
# 31.00    1
# 15.00    1
# 36.50    1
# 7.00     1
# 55.50    1
# 66.00    1
# 12.00    1
# 70.50    1
# 14.50    1
# 71.00    1
# 59.00    1
# 46.00    1
# 30.00    1
# 11.00    1
# 5.00     1
# 28.50    1
# 65.00    1
# 40.50    1
# 49.00    1
# 9.00     1
# 3.00     1
# 0.83     1
# Name: Age, dtype: int64

# %%
titanic_train['Pclass']
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 151    1
# 152    3
# 153    3
# 154    3
# 155    1
# Name: Pclass, Length: 156, dtype: int64

# %%
titanic_train['Pclass'].unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
titanic_train['Cabin'].unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2'], dtype=object)

# %%
titanic_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  156 non-null    int64
#  1   Survived     156 non-null    int64
#  2   Pclass       156 non-null    int64
#  3   Name         156 non-null    object
#  4   Sex          156 non-null    object
#  5   Age          126 non-null    float64
#  6   SibSp        156 non-null    int64
#  7   Parch        156 non-null    int64
#  8   Ticket       156 non-null    object
#  9   Fare         156 non-null    float64
#  10  Cabin        31 non-null     object
#  11  Embarked     155 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 14.8+ KB

# %%
char_cabin=titanic_train['Cabin'].astype(str)
char_cabin
# Out:
# 0       nan
# 1       C85
# 2       nan
# 3      C123
# 4       nan
#        ...
# 151      C2
# 152     nan
# 153     nan
# 154     nan
# 155     nan
# Name: Cabin, Length: 156, dtype: object

# %%
new_cabin=[cabin[0] for cabin in char_cabin]
new_cabin
# Out:
# ['n',
#  'C',
#  'n',
#  'C',
#  'n',
#  'n',
#  'E',
#  'n',
#  'n',
#  'n',
#  'G',
#  'C',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'D',
#  'n',
#  'A',
#  'n',
#  'n',
#  'n',
#  'C',
#  'n',
#  'n',
#  'n',
#  'B',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'D',
#  'n',
#  'B',
#  'C',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'B',
#  'C',
#  'n',
#  'n',
#  'n',
#  'F',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'F',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'C',
#  'n',
#  'n',
#  'n',
#  'E',
#  'n',
#  'n',
#  'n',
#  'A',
#  'D',
#  'n',
#  'n',
#  'n',
#  'n',
#  'D',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'C',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'B',
#  'n',
#  'n',
#  'n',
#  'n',
#  'E',
#  'D',
#  'n',
#  'n',
#  'n',
#  'F',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'D',
#  'C',
#  'n',
#  'B',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'F',
#  'n',
#  'n',
#  'C',
#  'n',
#  'n',
#  'n',
#  'n']

# %%
new_cabin=pd.Categorical(new_cabin)
new_cabin
# Out:
# [n, C, n, C, n, ..., C, n, n, n, n]
# Length: 156
# Categories (8, object): [A, B, C, D, E, F, G, n]

# %%
titanic_train['Cabin1']=new_cabin
titanic_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 151                  Pears, Mrs. Thomas (Edith Wearne)  female  22.0      1
# 152                                   Meo, Mr. Alfonzo    male  55.5      0
# 153                    van Billiard, Mr. Austin Blyler    male  40.5      0
# 154                              Olsen, Mr. Ole Martin    male   NaN      0
# 155                        Williams, Mr. Charles Duane    male  51.0      0
#
#      Parch            Ticket     Fare Cabin Embarked Cabin1
# 0        0         A/5 21171   7.2500   NaN        S      n
# 1        0          PC 17599  71.2833   C85        C      C
# 2        0  STON/O2. 3101282   7.9250   NaN        S      n
# 3        0            113803  53.1000  C123        S      C
# 4        0            373450   8.0500   NaN        S      n
# ..     ...               ...      ...   ...      ...    ...
# 151      0            113776  66.6000    C2        S      C
# 152      0        A.5. 11206   8.0500   NaN        S      n
# 153      2          A/5. 851  14.5000   NaN        S      n
# 154      0         Fa 265302   7.3125   NaN        S      n
# 155      1          PC 17597  61.3792   NaN        C      n
#
# [156 rows x 13 columns]

# %%
max(titanic_train['Fare'])
# Out:
# 263.0

# %%
titanic_train[titanic_train['Fare']==max(titanic_train['Fare'])]
# Out:
#     PassengerId  Survived  Pclass                            Name     Sex  \
# 27           28         0       1  Fortune, Mr. Charles Alexander    male
# 88           89         1       1      Fortune, Miss. Mabel Helen  female
#
#      Age  SibSp  Parch Ticket   Fare        Cabin Embarked Cabin1
# 27  19.0      3      2  19950  263.0  C23 C25 C27        S      C
# 88  23.0      3      2  19950  263.0  C23 C25 C27        S      C

# %%
np.where(titanic_train['Fare']==max(titanic_train['Fare']))
# Out:
# (array([27, 88], dtype=int64),)
